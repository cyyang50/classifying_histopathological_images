# %% [markdown]
# # Set Up

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# change to your working directory
#%cd "/content/drive/MyDrive/shared folder/Master_Thesis"
# %cd "/content/drive/MyDrive/shared_folder/Master_Thesis"
# Out:
# /content/drive/.shortcut-targets-by-id/1lHcON5EHJDerZlJ2mPUGsY4w6iFLBKs5/shared_folder/Master_Thesis

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPool2D, BatchNormalization, Dropout, Input, Activation, Reshape, GlobalMaxPooling2D, GlobalAveragePooling2D,  Add
from tensorflow.keras.applications import VGG16, InceptionV3, ResNet50, ResNet50V2, MobileNetV3Large
from tensorflow.keras.applications.resnet50 import preprocess_input, ResNet50
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.constraints import MinMaxNorm, MaxNorm
from sklearn.preprocessing import OneHotEncoder
import os ,random
import shutil
import sys
import matplotlib.pyplot as plt
import h5py
import pickle
from keras.preprocessing.image import load_img, img_to_array, array_to_img

# %%
print("GPU Available: ", tf.test.is_gpu_available())
print(tf.__version__)
# Out:
# WARNING:tensorflow:From <ipython-input-4-53c8631e9cc1>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# 2.8.0

# %%
# Original Dataset
Source_dir_train1 = "./Images/DANN/Source/LC25000_mix_data_128_train1.pkl"
Source_dir_train2 = "./Images/DANN/Source/LC25000_mix_data_128_train2.pkl"
Source_dir_train3 = "./Images/DANN/Source/LC25000_mix_data_128_train3.pkl"
Source_dir_train4 = "./Images/DANN/Source/LC25000_mix_data_128_train4.pkl"
Source_dir_train5 = "./Images/DANN/Source/LC25000_mix_data_128_train5.pkl"
Source_dir_test1 = "./Images/DANN/Source/LC25000_mix_data_128_test1.pkl"
Source_dir_test2 = "./Images/DANN/Source/LC25000_mix_data_128_test2.pkl"


Target_dir_train = os.path.abspath("./Images/DANN/Target/TCGA_mix_data_128_train.pkl")
Target_dir_test = os.path.abspath("./Images/DANN/Target/TCGA_mix_data_128_test.pkl")

# Cyclegan Dataset

Target_cyclegan_dir_train = os.path.abspath("./Images/DANN/Target_cyclegan/TCGA_cyclegan_mix_data_128_train.pkl")
Target_cyclegan_dir_test = os.path.abspath("./Images/DANN/Target_cyclegan/TCGA_cyclegan_mix_data_128_test.pkl")

# %%
BATCH_SIZE = 64
CHANNELS = 3
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
EPOCH = 5
learning_rate =1e-4

# %% [markdown]
# # Loading Dataset

# %% [markdown]
# ## LC25000 Dataset

# %%
# LC25000 Dataset
with open(os.path.abspath(Source_dir_train1), "rb") as f:
    LC25000_train1 = pickle.load(f)
with open(os.path.abspath(Source_dir_train2), "rb") as f:
    LC25000_train2 = pickle.load(f)
with open(os.path.abspath(Source_dir_train3), "rb") as f:
    LC25000_train3 = pickle.load(f)
with open(os.path.abspath(Source_dir_train4), "rb") as f:
    LC25000_train4 = pickle.load(f)
with open(os.path.abspath(Source_dir_train5), "rb") as f:
    LC25000_train5 = pickle.load(f)
with open(os.path.abspath(Source_dir_test1), "rb") as f:
    LC25000_test1 = pickle.load(f)
with open(os.path.abspath(Source_dir_test2), "rb") as f:
    LC25000_test2 = pickle.load(f)

# %%
LC25000_train_data = LC25000_train1['train'] + LC25000_train2['train'] + LC25000_train3['train'] + LC25000_train4['train'] + LC25000_train5['train']
LC25000_train_labels = np.concatenate((LC25000_train1['train_label'],LC25000_train2['train_label'],LC25000_train3['train_label'],LC25000_train4['train_label'],LC25000_train5['train_label']))
LC25000_test_data = LC25000_test1['test'] + LC25000_test2['test']
LC25000_test_labels = np.concatenate((LC25000_test1['test_label'],LC25000_test2['test_label']))

# %%
# random show images
plt.subplots(1,2,figsize=(8,8))
ax1=plt.subplot(1,2,1)
sample1 = random.choice(LC25000_train_data)
img1 = array_to_img(sample1)
plt.title("LC25000_train_data")
plt.imshow(img1)
ax1=plt.subplot(1,2,2)
sample2 = random.choice(LC25000_test_data)
img2 = array_to_img(sample2)
plt.title("LC25000_test_data")
plt.imshow(img2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def convert(data_list):
    for i in range(len(data_list)): data_list[i]=data_list[i]/255

# %%
LC25000_train_lab = tf.one_hot(LC25000_train_labels, depth=3)
LC25000_test_lab = tf.one_hot(LC25000_test_labels, depth=3)

# %%
LC25000_train_data = np.array(LC25000_train_data, dtype=np.float32)
LC25000_test_data = np.array(LC25000_test_data, dtype=np.float32)

# %%
print("The shape of LC25000_train_data: ", LC25000_train_data.shape)
print("The shape of LC25000_train_labels: ", LC25000_train_labels.shape)
print("The shape of LC25000_test_data: ", LC25000_test_data.shape)
print("The shape of LC25000_test_labels: " ,LC25000_test_labels.shape)
# Out:
# The shape of LC25000_train_data:  (6400, 128, 128, 3)
# The shape of LC25000_train_labels:  (6400,)
# The shape of LC25000_test_data:  (1600, 128, 128, 3)
# The shape of LC25000_test_labels:  (1600,)

# %%
import gc
gc.collect()
# Out:
# 1629

# %% [markdown]
# ## TCGA Dataset

# %%
# TCGA Dataset
with open(os.path.abspath(Target_dir_train), "rb") as f:
    TCGA_train = pickle.load(f)
with open(os.path.abspath(Target_dir_test), "rb") as f:
    TCGA_test = pickle.load(f)

# %%
TCGA_train_data = TCGA_train['train']
TCGA_train_labels = TCGA_train['train_label']
TCGA_test_data = TCGA_test['test']
TCGA_test_labels = TCGA_test['test_label']

# %%
# random show images
plt.subplots(1,2,figsize=(10,10))
ax1=plt.subplot(1,2,1)
sample1 = random.choice(TCGA_train_data)
img1 = array_to_img(sample1)
plt.title("TCGA_train_data")
plt.imshow(img1)
ax1=plt.subplot(1,2,2)
sample2 = random.choice(TCGA_test_data)
img2 = array_to_img(sample2)
plt.title("TCGA_test_data")
plt.imshow(img2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
TCGA_train_lab = tf.one_hot(TCGA_train_labels, depth=3)
TCGA_test_lab = tf.one_hot(TCGA_test_labels, depth=3)

# %%
TCGA_train_data = np.array(TCGA_train_data, dtype=np.float32)
TCGA_test_data = np.array(TCGA_test_data, dtype=np.float32)

# %%
print("The shape of TCGA_train_data: ", TCGA_train_data.shape)
print("The shape of TCGA_train_labels: ", TCGA_train_labels.shape)
print("The shape of TCGA_test_data: ", TCGA_test_data.shape)
print("The shape of TCGA_test_labels: " , TCGA_test_labels.shape)
# Out:
# The shape of TCGA_train_data:  (6400, 128, 128, 3)
# The shape of TCGA_train_labels:  (6400,)
# The shape of TCGA_test_data:  (6400, 128, 128, 3)
# The shape of TCGA_test_labels:  (6400,)

# %% [markdown]
# # Domain Adaptation

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Feature Extractor - ResNet50V2

# %%
resnet50 = ResNet50(include_top=False, input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, CHANNELS), pooling="avg")

first_layer = resnet50.get_layer('conv5_block2_out')
inputs = Input(first_layer.output_shape[1:])

for layer in resnet50.layers[resnet50.layers.index(first_layer)+1:]:
    if layer.name == "conv5_block3_1_conv":
        x = layer(inputs)
    elif layer.name == "conv5_block3_add":  # change name
        x = layer([inputs, x])
    else:
        if layer.name == "conv5_block3_preact_bn":
            pass
        else:
            x = layer(x)

first_blocks = Model(resnet50.input, first_layer.output)
last_block = Model(inputs, x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step

# %%
def load_resnet50(path="./Model/DANN_Model/resnet50_last_block.hdf5"):
    model = load_model(path)
    for i in range(len(model.layers)):
        if model.layers[i].__class__.__name__ == "BatchNormalization":
            model.layers[i].trainable = False
    return model

last_block.summary()
last_block.save("./Model/DANN_Model/resnet50_last_block.hdf5")
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 4, 4, 2048)  0           []
#                                 ]
#
#  conv5_block3_1_conv (Conv2D)   (None, 4, 4, 512)    1049088     ['input_2[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_1_conv[1][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_1_bn[1][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block3_1_relu[1][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_2_conv[1][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_2_bn[1][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block3_2_relu[1][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block3_3_conv[1][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 4, 4, 2048)   0           ['input_2[0][0]',
#                                                                   'conv5_block3_3_bn[1][0]']
#
#  conv5_block3_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block3_add[1][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[1][0]']
#  2D)
#
# ==================================================================================================
# Total params: 4,471,808
# Trainable params: 4,465,664
# Non-trainable params: 6,144
# __________________________________________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ### Extract the features

# %%
LC25000_train_data_ex = first_blocks.predict(preprocess_input(np.stack(LC25000_train_data)))
TCGA_train_data_ex = first_blocks.predict(preprocess_input(np.stack(TCGA_train_data)))
TCGA_test_data_ex = first_blocks.predict(preprocess_input(np.stack(TCGA_test_data)))

print("LC25000_train_data (source) shape: %s"%str(LC25000_train_data.shape))
print("TCGA_train_data (target) shape: %s"%str(TCGA_train_data.shape))
# Out:
# LC25000_train_data (source) shape: (6400, 128, 128, 3)
# TCGA_train_data (target) shape: (6400, 128, 128, 3)

# %% [markdown]
# ### Prepare Datasets

# %%
source_dataset = tf.data.Dataset.from_tensor_slices((LC25000_train_data_ex, LC25000_train_lab)).shuffle(1000).batch(BATCH_SIZE*2)
da_dataset = tf.data.Dataset.from_tensor_slices((LC25000_train_data_ex, LC25000_train_lab, TCGA_train_data_ex, TCGA_train_lab)).shuffle(1000).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((TCGA_test_data_ex, TCGA_test_lab)).shuffle(1000).batch(BATCH_SIZE*2) #Test Dataset over Target Domain
test_dataset2 = tf.data.Dataset.from_tensor_slices((TCGA_train_data_ex, TCGA_train_lab)).shuffle(1000).batch(BATCH_SIZE*2) #Test Dataset over Target (used for training)

# %% [markdown]
# ### ResNet50V2 Model

# %%
feature_extractor_resnet = load_resnet50()

class DANN_resnet(Model):
    def __init__(self):
        super().__init__()
        
        #Feature Extractor
        self.ResNet_load = feature_extractor_resnet
        
        #Label Predictor
        self.max_norm = 0.5
        self.dropout= 0.5
        self.label_predictor_layer0 = Dense(1024, activation="relu",
                                            kernel_constraint=MaxNorm(self.max_norm),
                                            bias_constraint=MaxNorm(self.max_norm))
        self.label_predictor_layer1 = Dropout(self.dropout)
        self.label_predictor_layer2 = Dense(1024, activation="relu",
                                            kernel_constraint=MaxNorm(self.max_norm),
                                            bias_constraint=MaxNorm(self.max_norm))
        self.label_predictor_layer3 = Dropout(self.dropout)
        self.label_predictor_layer4 = Dense(3, activation=None)
        
        #Domain Predictor
        self.domain_predictor_layer0 = GradientReversalLayer()
        self.domain_predictor_layer1 = Dense(100, activation='relu')
        self.domain_predictor_layer2 = Dense(2, activation=None)
        
    def call(self, x, train=False, source_train=True, lamda=1.0):
        #Feature Extractor
        x = self.ResNet_load(x)
        #print("x:", x)
     

        feature = tf.reshape(x, [-1, 32 * 32 * 2])
        #print("feature: ", feature)
        
        #Label Predictor
        if source_train is True:
            feature_slice = feature
            #print("feature_slice: ",feature_slice)
        else:
            feature_slice = tf.slice(feature, [0, 0], [feature.shape[0] // 2, -1])
            #print("feature_slice: ",feature_slice)
        
        lp_x = self.label_predictor_layer0(feature_slice)
        lp_x = self.label_predictor_layer1(lp_x)
        lp_x = self.label_predictor_layer2(lp_x)
        lp_x = self.label_predictor_layer3(lp_x)
        l_logits = self.label_predictor_layer4(lp_x)
        
        #Domain Predictor
        if source_train is True:
            #print("l_logits: " ,l_logits)
            return l_logits
        else:
            dp_x = self.domain_predictor_layer0(feature, lamda)    #GradientReversalLayer
            dp_x = self.domain_predictor_layer1(dp_x)
            d_logits = self.domain_predictor_layer2(dp_x)
            #print("l_logits-1: " ,l_logits)
            #print("d_logits-1", d_logits)
            return l_logits, d_logits


#model = DANN_resnet()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ## Gradient Reversal Layer

# %%
@tf.custom_gradient
def gradient_reverse(x, lamda=1.0):
    y = tf.identity(x)
    
    def grad(dy):
        return lamda * -dy, None
    
    return y, grad


class GradientReversalLayer(tf.keras.layers.Layer):
    def __init__(self):
        super().__init__()
    
    def call(self, x, lamda=1.0):
        return gradient_reverse(x, lamda)

# %% [markdown]
# ## Define Loss and Optimizer

# %%
def loss_func(input_logits, target_labels):
    return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=input_logits, labels=target_labels))


def get_loss(l_logits, labels, d_logits=None, domain=None):
    if d_logits is None:
        #print("l_logits",l_logits)
        #print("labels",labels)
        return loss_func(l_logits, labels)
    else:
        #print("l_logits-2",l_logits)
        #print("labels-2",labels)
        #print("d_logits-2",d_logits)
        #print("domain-2",domain.shape)        
        return loss_func(l_logits, labels) + loss_func(d_logits, domain)

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate= learning_rate,
    decay_steps=10000,
    decay_rate=0.9)

model_optimizer = tf.optimizers.Adam(learning_rate=lr_schedule)
#model_optimizer = tf.optimizers.SGD(learning_rate=lr_schedule)


#model_optimizer = tf.optimizers.Adam(learning_rate=1e-4)
# model_optimizer = tf.optimizers.SGD(learning_rate=1e-4)

# %% [markdown]
# ## Configuration of Training

# %%
domain_labels = np.vstack([np.tile([1., 0.], [BATCH_SIZE, 1]),
                           np.tile([0., 1.], [BATCH_SIZE, 1])])
domain_labels = domain_labels.astype('float32')

epoch_accuracy = tf.keras.metrics.CategoricalAccuracy()

source_acc = []  # Source Domain Accuracy while Source-only Training
da_acc = []      # Source Domain Accuracy while DA-training
test_acc = []    # Testing Dataset (Target Domain) Accuracy 
test2_acc = []   # Target Domain (used for Training) Accuracy

def reset_list():
    source_acc.clear() 
    da_acc.clear()
    test_acc.clear()
    test2_acc.clear()

# %%
@tf.function
def train_step_source(s_images, s_labels, lamda=1.0):
    images = s_images
    labels = s_labels
    
    with tf.GradientTape() as tape:
        output = model(images, train=True, source_train=True, lamda=lamda)
        
        model_loss = get_loss(output, labels)
        epoch_accuracy(output, labels)
        
    gradients_mdan = tape.gradient(model_loss, model.trainable_variables)
    model_optimizer.apply_gradients(zip(gradients_mdan, model.trainable_variables))


@tf.function
def train_step_da(s_images, s_labels, t_images=None, t_labels=None, lamda=1.0):
    images = tf.concat([s_images, t_images], 0)
    labels = s_labels
    
    with tf.GradientTape() as tape:
        output = model(images, train=True, source_train=False, lamda=lamda)
        
        model_loss = get_loss(output[0], labels, output[1], domain_labels)
        epoch_accuracy(output[0], labels)
        
    gradients_mdan = tape.gradient(model_loss, model.trainable_variables)
    model_optimizer.apply_gradients(zip(gradients_mdan, model.trainable_variables))


@tf.function
def test_step(t_images, t_labels):
    images = t_images
    labels = t_labels
    
    output = model(images, train=False, source_train=True)
    epoch_accuracy(output, labels)



def train(train_mode, epochs):
    
    if train_mode == 'source':
        dataset = source_dataset
        train_func = train_step_source
        acc_list = source_acc
    elif train_mode == 'domain-adaptation':
        dataset = da_dataset
        train_func = train_step_da
        acc_list = da_acc
    else:
        raise ValueError("Unknown training Mode")
    

    for epoch in range(epochs):
        p = float(epoch) / epochs
        lamda = 2 / (1 + np.exp(-gamma * p, dtype=np.float32)) - 1
        lamda = lamda.astype('float32')

        
        for batch in dataset:
            train_func(*batch, lamda=lamda)
        
        print("Training: Epoch {} :\t Source Accuracy : {:.3%}".format(epoch, epoch_accuracy.result()), end='  |  ')
        acc_list.append(epoch_accuracy.result())
        test()
        epoch_accuracy.reset_states()


def test():
    epoch_accuracy.reset_states()
    
    #Testing Dataset (Target Domain)

    for batch in test_dataset:
        test_step(*batch)
        
    print("Testing Accuracy : {:.3%}".format(epoch_accuracy.result()), end='  |  ')
    test_acc.append(epoch_accuracy.result())
    epoch_accuracy.reset_states()
    
    #Target Domain (used for Training)
    for batch in test_dataset2:
        test_step(*batch)
    
    print("Target Domain Accuracy : {:.3%}".format(epoch_accuracy.result()))
    test2_acc.append(epoch_accuracy.result())
    epoch_accuracy.reset_states()

# %% [markdown]
# # Training

# %% [markdown]
# ### domain-adaptation train :  RMS=1e-5, gamma = 5

# %%
reset_list()

EPOCH= 100
model = DANN_resnet()
gamma = 5
learning_rate = 1e-5
model_optimizer = tf.optimizers.RMSprop(learning_rate=lr_schedule)
train('domain-adaptation', EPOCH)

#Plot Results
x_axis = [i for i in range(0, EPOCH)]

plt.title("Accuracy of DANN Model - Domain-adaptation Training")
plt.plot(x_axis, da_acc, label="source accuracy")
plt.plot(x_axis, test_acc, label="testing accuracy")
plt.plot(x_axis, test2_acc, label="target accuracy")
plt.legend()
# Out:
# Training: Epoch 0 :	 Source Accuracy : 97.828%  |  Testing Accuracy : 26.750%  |  Target Domain Accuracy : 26.703%
# Training: Epoch 1 :	 Source Accuracy : 97.719%  |  Testing Accuracy : 27.641%  |  Target Domain Accuracy : 27.625%
# Training: Epoch 2 :	 Source Accuracy : 97.438%  |  Testing Accuracy : 29.750%  |  Target Domain Accuracy : 29.672%
# Training: Epoch 3 :	 Source Accuracy : 97.859%  |  Testing Accuracy : 29.578%  |  Target Domain Accuracy : 29.656%
# Training: Epoch 4 :	 Source Accuracy : 97.688%  |  Testing Accuracy : 28.156%  |  Target Domain Accuracy : 28.109%
# Training: Epoch 5 :	 Source Accuracy : 97.844%  |  Testing Accuracy : 30.266%  |  Target Domain Accuracy : 30.219%
# Training: Epoch 6 :	 Source Accuracy : 97.703%  |  Testing Accuracy : 28.141%  |  Target Domain Accuracy : 28.109%
# Training: Epoch 7 :	 Source Accuracy : 97.609%  |  Testing Accuracy : 28.828%  |  Target Domain Accuracy : 28.859%
# Training: Epoch 8 :	 Source Accuracy : 97.859%  |  Testing Accuracy : 30.437%  |  Target Domain Accuracy : 30.375%
# Training: Epoch 9 :	 Source Accuracy : 97.609%  |  Testing Accuracy : 30.750%  |  Target Domain Accuracy : 30.484%
# Training: Epoch 10 :	 Source Accuracy : 97.516%  |  Testing Accuracy : 30.000%  |  Target Domain Accuracy : 29.781%
# Training: Epoch 11 :	 Source Accuracy : 97.797%  |  Testing Accuracy : 26.812%  |  Target Domain Accuracy : 26.750%
# Training: Epoch 12 :	 Source Accuracy : 97.422%  |  Testing Accuracy : 28.375%  |  Target Domain Accuracy : 28.484%
# Training: Epoch 13 :	 Source Accuracy : 97.547%  |  Testing Accuracy : 28.062%  |  Target Domain Accuracy : 28.094%
# Training: Epoch 14 :	 Source Accuracy : 97.781%  |  Testing Accuracy : 31.250%  |  Target Domain Accuracy : 31.141%
# Training: Epoch 15 :	 Source Accuracy : 97.703%  |  Testing Accuracy : 28.891%  |  Target Domain Accuracy : 29.203%
# Training: Epoch 16 :	 Source Accuracy : 97.578%  |  Testing Accuracy : 25.891%  |  Target Domain Accuracy : 25.594%
# Training: Epoch 17 :	 Source Accuracy : 97.578%  |  Testing Accuracy : 27.906%  |  Target Domain Accuracy : 28.109%
# Training: Epoch 18 :	 Source Accuracy : 97.766%  |  Testing Accuracy : 27.875%  |  Target Domain Accuracy : 28.141%
# Training: Epoch 19 :	 Source Accuracy : 97.672%  |  Testing Accuracy : 27.828%  |  Target Domain Accuracy : 28.141%
# Training: Epoch 20 :	 Source Accuracy : 97.797%  |  Testing Accuracy : 21.969%  |  Target Domain Accuracy : 21.875%
# Training: Epoch 21 :	 Source Accuracy : 98.000%  |  Testing Accuracy : 25.344%  |  Target Domain Accuracy : 25.094%
# Training: Epoch 22 :	 Source Accuracy : 97.594%  |  Testing Accuracy : 28.906%  |  Target Domain Accuracy : 29.047%
# Training: Epoch 23 :	 Source Accuracy : 97.562%  |  Testing Accuracy : 30.609%  |  Target Domain Accuracy : 30.328%
# Training: Epoch 24 :	 Source Accuracy : 97.875%  |  Testing Accuracy : 33.922%  |  Target Domain Accuracy : 33.516%
# Training: Epoch 25 :	 Source Accuracy : 97.641%  |  Testing Accuracy : 41.000%  |  Target Domain Accuracy : 40.422%
# Training: Epoch 26 :	 Source Accuracy : 97.625%  |  Testing Accuracy : 47.438%  |  Target Domain Accuracy : 47.141%
# Training: Epoch 27 :	 Source Accuracy : 97.453%  |  Testing Accuracy : 49.219%  |  Target Domain Accuracy : 49.281%
# Training: Epoch 28 :	 Source Accuracy : 97.516%  |  Testing Accuracy : 48.937%  |  Target Domain Accuracy : 48.969%
# Training: Epoch 29 :	 Source Accuracy : 97.219%  |  Testing Accuracy : 48.750%  |  Target Domain Accuracy : 48.344%
# Training: Epoch 30 :	 Source Accuracy : 97.594%  |  Testing Accuracy : 49.078%  |  Target Domain Accuracy : 49.062%
# Training: Epoch 31 :	 Source Accuracy : 97.562%  |  Testing Accuracy : 49.094%  |  Target Domain Accuracy : 49.062%
# Training: Epoch 32 :	 Source Accuracy : 98.156%  |  Testing Accuracy : 49.453%  |  Target Domain Accuracy : 49.484%
# Training: Epoch 33 :	 Source Accuracy : 97.656%  |  Testing Accuracy : 49.578%  |  Target Domain Accuracy : 49.625%
# Training: Epoch 34 :	 Source Accuracy : 97.828%  |  Testing Accuracy : 49.250%  |  Target Domain Accuracy : 49.250%
# Training: Epoch 35 :	 Source Accuracy : 97.844%  |  Testing Accuracy : 48.812%  |  Target Domain Accuracy : 48.516%
# Training: Epoch 36 :	 Source Accuracy : 97.797%  |  Testing Accuracy : 48.687%  |  Target Domain Accuracy : 48.313%
# Training: Epoch 37 :	 Source Accuracy : 97.625%  |  Testing Accuracy : 49.219%  |  Target Domain Accuracy : 49.047%
# Training: Epoch 38 :	 Source Accuracy : 97.672%  |  Testing Accuracy : 49.750%  |  Target Domain Accuracy : 49.719%
# Training: Epoch 39 :	 Source Accuracy : 97.625%  |  Testing Accuracy : 49.609%  |  Target Domain Accuracy : 49.687%
# Training: Epoch 40 :	 Source Accuracy : 97.547%  |  Testing Accuracy : 49.000%  |  Target Domain Accuracy : 49.094%
# Training: Epoch 41 :	 Source Accuracy : 97.734%  |  Testing Accuracy : 48.547%  |  Target Domain Accuracy : 48.156%
# Training: Epoch 42 :	 Source Accuracy : 97.688%  |  Testing Accuracy : 48.297%  |  Target Domain Accuracy : 47.922%
# Training: Epoch 43 :	 Source Accuracy : 97.531%  |  Testing Accuracy : 49.187%  |  Target Domain Accuracy : 49.203%
# Training: Epoch 44 :	 Source Accuracy : 97.781%  |  Testing Accuracy : 48.906%  |  Target Domain Accuracy : 48.875%
# Training: Epoch 45 :	 Source Accuracy : 97.859%  |  Testing Accuracy : 48.719%  |  Target Domain Accuracy : 48.188%
# Training: Epoch 46 :	 Source Accuracy : 97.938%  |  Testing Accuracy : 48.391%  |  Target Domain Accuracy : 47.719%
# Training: Epoch 47 :	 Source Accuracy : 97.688%  |  Testing Accuracy : 47.781%  |  Target Domain Accuracy : 47.484%
# Training: Epoch 48 :	 Source Accuracy : 97.844%  |  Testing Accuracy : 48.625%  |  Target Domain Accuracy : 48.266%
# Training: Epoch 49 :	 Source Accuracy : 97.859%  |  Testing Accuracy : 48.828%  |  Target Domain Accuracy : 48.703%
# Training: Epoch 50 :	 Source Accuracy : 97.844%  |  Testing Accuracy : 48.891%  |  Target Domain Accuracy : 48.687%
# Training: Epoch 51 :	 Source Accuracy : 97.734%  |  Testing Accuracy : 49.422%  |  Target Domain Accuracy : 49.094%
# Training: Epoch 52 :	 Source Accuracy : 97.969%  |  Testing Accuracy : 49.078%  |  Target Domain Accuracy : 48.937%
# Training: Epoch 53 :	 Source Accuracy : 97.594%  |  Testing Accuracy : 48.547%  |  Target Domain Accuracy : 48.203%
# Training: Epoch 54 :	 Source Accuracy : 97.750%  |  Testing Accuracy : 48.594%  |  Target Domain Accuracy : 48.219%
# Training: Epoch 55 :	 Source Accuracy : 97.781%  |  Testing Accuracy : 48.641%  |  Target Domain Accuracy : 48.297%
# Training: Epoch 56 :	 Source Accuracy : 97.672%  |  Testing Accuracy : 49.375%  |  Target Domain Accuracy : 49.312%
# Training: Epoch 57 :	 Source Accuracy : 97.812%  |  Testing Accuracy : 49.547%  |  Target Domain Accuracy : 49.609%
# Training: Epoch 58 :	 Source Accuracy : 97.844%  |  Testing Accuracy : 49.297%  |  Target Domain Accuracy : 49.406%
# Training: Epoch 59 :	 Source Accuracy : 97.672%  |  Testing Accuracy : 49.078%  |  Target Domain Accuracy : 49.062%
# Training: Epoch 60 :	 Source Accuracy : 97.922%  |  Testing Accuracy : 48.031%  |  Target Domain Accuracy : 47.172%
# Training: Epoch 61 :	 Source Accuracy : 97.656%  |  Testing Accuracy : 47.750%  |  Target Domain Accuracy : 47.094%
# Training: Epoch 62 :	 Source Accuracy : 97.875%  |  Testing Accuracy : 48.250%  |  Target Domain Accuracy : 47.781%
# Training: Epoch 63 :	 Source Accuracy : 97.734%  |  Testing Accuracy : 48.484%  |  Target Domain Accuracy : 48.141%
# Training: Epoch 64 :	 Source Accuracy : 97.500%  |  Testing Accuracy : 47.750%  |  Target Domain Accuracy : 46.953%
# Training: Epoch 65 :	 Source Accuracy : 97.922%  |  Testing Accuracy : 47.891%  |  Target Domain Accuracy : 46.969%
# Training: Epoch 66 :	 Source Accuracy : 98.109%  |  Testing Accuracy : 47.031%  |  Target Domain Accuracy : 46.266%
# Training: Epoch 67 :	 Source Accuracy : 97.891%  |  Testing Accuracy : 47.219%  |  Target Domain Accuracy : 46.703%
# Training: Epoch 68 :	 Source Accuracy : 97.844%  |  Testing Accuracy : 47.672%  |  Target Domain Accuracy : 47.156%
# Training: Epoch 69 :	 Source Accuracy : 97.781%  |  Testing Accuracy : 48.500%  |  Target Domain Accuracy : 48.094%
# Training: Epoch 70 :	 Source Accuracy : 97.859%  |  Testing Accuracy : 48.906%  |  Target Domain Accuracy : 48.641%
# Training: Epoch 71 :	 Source Accuracy : 97.875%  |  Testing Accuracy : 48.313%  |  Target Domain Accuracy : 47.906%
# Training: Epoch 72 :	 Source Accuracy : 97.516%  |  Testing Accuracy : 46.734%  |  Target Domain Accuracy : 45.797%
# Training: Epoch 73 :	 Source Accuracy : 97.906%  |  Testing Accuracy : 45.719%  |  Target Domain Accuracy : 45.406%
# Training: Epoch 74 :	 Source Accuracy : 97.828%  |  Testing Accuracy : 46.797%  |  Target Domain Accuracy : 46.281%
# Training: Epoch 75 :	 Source Accuracy : 97.891%  |  Testing Accuracy : 47.391%  |  Target Domain Accuracy : 46.984%
# Training: Epoch 76 :	 Source Accuracy : 97.875%  |  Testing Accuracy : 48.156%  |  Target Domain Accuracy : 47.813%
# Training: Epoch 77 :	 Source Accuracy : 97.984%  |  Testing Accuracy : 47.516%  |  Target Domain Accuracy : 46.766%
# Training: Epoch 78 :	 Source Accuracy : 98.109%  |  Testing Accuracy : 46.531%  |  Target Domain Accuracy : 45.875%
# Training: Epoch 79 :	 Source Accuracy : 97.812%  |  Testing Accuracy : 46.531%  |  Target Domain Accuracy : 45.984%
# Training: Epoch 80 :	 Source Accuracy : 97.766%  |  Testing Accuracy : 47.063%  |  Target Domain Accuracy : 46.359%
# Training: Epoch 81 :	 Source Accuracy : 97.734%  |  Testing Accuracy : 47.703%  |  Target Domain Accuracy : 47.250%
# Training: Epoch 82 :	 Source Accuracy : 97.938%  |  Testing Accuracy : 48.875%  |  Target Domain Accuracy : 48.766%
# Training: Epoch 83 :	 Source Accuracy : 97.922%  |  Testing Accuracy : 48.641%  |  Target Domain Accuracy : 48.406%
# Training: Epoch 84 :	 Source Accuracy : 97.891%  |  Testing Accuracy : 48.984%  |  Target Domain Accuracy : 48.812%
# Training: Epoch 85 :	 Source Accuracy : 97.891%  |  Testing Accuracy : 49.078%  |  Target Domain Accuracy : 48.922%
# Training: Epoch 86 :	 Source Accuracy : 97.703%  |  Testing Accuracy : 49.703%  |  Target Domain Accuracy : 49.453%
# Training: Epoch 87 :	 Source Accuracy : 97.781%  |  Testing Accuracy : 49.984%  |  Target Domain Accuracy : 49.828%
# Training: Epoch 88 :	 Source Accuracy : 97.922%  |  Testing Accuracy : 50.000%  |  Target Domain Accuracy : 49.797%
# Training: Epoch 89 :	 Source Accuracy : 97.797%  |  Testing Accuracy : 49.937%  |  Target Domain Accuracy : 49.922%
# Training: Epoch 90 :	 Source Accuracy : 97.875%  |  Testing Accuracy : 49.875%  |  Target Domain Accuracy : 49.766%
# Training: Epoch 91 :	 Source Accuracy : 97.672%  |  Testing Accuracy : 49.703%  |  Target Domain Accuracy : 49.594%
# Training: Epoch 92 :	 Source Accuracy : 98.000%  |  Testing Accuracy : 50.031%  |  Target Domain Accuracy : 49.844%
# Training: Epoch 93 :	 Source Accuracy : 97.453%  |  Testing Accuracy : 50.047%  |  Target Domain Accuracy : 49.609%
# Training: Epoch 94 :	 Source Accuracy : 97.656%  |  Testing Accuracy : 50.625%  |  Target Domain Accuracy : 49.687%
# Training: Epoch 95 :	 Source Accuracy : 97.766%  |  Testing Accuracy : 50.266%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 96 :	 Source Accuracy : 97.453%  |  Testing Accuracy : 50.266%  |  Target Domain Accuracy : 49.828%
# Training: Epoch 97 :	 Source Accuracy : 97.781%  |  Testing Accuracy : 50.641%  |  Target Domain Accuracy : 49.656%
# Training: Epoch 98 :	 Source Accuracy : 97.828%  |  Testing Accuracy : 50.422%  |  Target Domain Accuracy : 49.875%
# Training: Epoch 99 :	 Source Accuracy : 97.984%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%

# %%
import pandas as pd
lst1 = range(100)
lst2 = range(100)
lst3 = range(100)
train_data = pd.DataFrame(
    {"source accuracy": da_acc,
     "testing accuracy": test_acc,
     "target accuracy": test2_acc
    })
train_data.to_csv("./Model/DANN_Model/DANN/DANN_Resnet_RMS_1e-5_g5.csv")

# %% [markdown]
# ### source train : SGD=1e-5, gamma = 5

# %%
reset_list()

EPOCH= 100
model = DANN_resnet()
gamma = 5
learning_rate = 1e-5
model_optimizer = tf.optimizers.RMSprop(learning_rate=lr_schedule)
# model_optimizer = tf.optimizers.SGD(learning_rate=lr_schedule)
# model_optimizer = tf.optimizers.RMSprop(learning_rate=1e-5)
train('source', EPOCH)

#Plot Results
x_axis = [i for i in range(0, EPOCH)]

plt.title("Accuracy of DANN Model - Domain-adaptation Training")
plt.plot(x_axis, source_acc, label="source accuracy")
plt.plot(x_axis, test_acc, label="testing accuracy")
plt.plot(x_axis, test2_acc, label="target accuracy")
plt.legend()
# Out:
# Training: Epoch 0 :	 Source Accuracy : 94.781%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 1 :	 Source Accuracy : 97.078%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 2 :	 Source Accuracy : 97.391%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 3 :	 Source Accuracy : 98.047%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 4 :	 Source Accuracy : 98.328%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 5 :	 Source Accuracy : 98.500%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 6 :	 Source Accuracy : 98.781%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 7 :	 Source Accuracy : 99.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 8 :	 Source Accuracy : 99.344%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 9 :	 Source Accuracy : 99.469%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 10 :	 Source Accuracy : 99.500%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 11 :	 Source Accuracy : 99.328%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 12 :	 Source Accuracy : 99.531%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 13 :	 Source Accuracy : 99.609%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 14 :	 Source Accuracy : 99.641%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 15 :	 Source Accuracy : 99.656%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 16 :	 Source Accuracy : 99.672%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 17 :	 Source Accuracy : 99.687%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 18 :	 Source Accuracy : 99.187%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 19 :	 Source Accuracy : 99.766%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 20 :	 Source Accuracy : 99.891%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 21 :	 Source Accuracy : 99.766%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 22 :	 Source Accuracy : 99.828%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 23 :	 Source Accuracy : 99.813%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 24 :	 Source Accuracy : 99.813%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 25 :	 Source Accuracy : 99.406%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 26 :	 Source Accuracy : 99.547%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 27 :	 Source Accuracy : 99.969%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 28 :	 Source Accuracy : 99.781%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 29 :	 Source Accuracy : 99.344%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 30 :	 Source Accuracy : 99.937%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 31 :	 Source Accuracy : 99.328%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 32 :	 Source Accuracy : 99.859%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 33 :	 Source Accuracy : 99.719%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 34 :	 Source Accuracy : 99.969%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 35 :	 Source Accuracy : 99.828%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 36 :	 Source Accuracy : 99.844%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 37 :	 Source Accuracy : 99.703%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 38 :	 Source Accuracy : 99.984%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 39 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 40 :	 Source Accuracy : 99.687%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 41 :	 Source Accuracy : 99.844%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 42 :	 Source Accuracy : 99.609%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 43 :	 Source Accuracy : 99.828%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 44 :	 Source Accuracy : 99.922%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 45 :	 Source Accuracy : 99.953%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 46 :	 Source Accuracy : 99.813%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 47 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 48 :	 Source Accuracy : 99.516%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 49 :	 Source Accuracy : 99.937%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 50 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 51 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 52 :	 Source Accuracy : 99.406%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 53 :	 Source Accuracy : 99.875%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 54 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 55 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 56 :	 Source Accuracy : 99.750%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 57 :	 Source Accuracy : 99.984%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 58 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 59 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 60 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 61 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 62 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 63 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 64 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 65 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 66 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 67 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 68 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 69 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 70 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 71 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 72 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 73 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 74 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 75 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 76 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 77 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 78 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 79 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 80 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 81 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 82 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 83 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 84 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 85 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 86 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 87 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 88 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 89 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 90 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 91 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 92 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 93 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 94 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 95 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 96 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 97 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 98 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%
# Training: Epoch 99 :	 Source Accuracy : 100.000%  |  Testing Accuracy : 50.250%  |  Target Domain Accuracy : 49.812%

# %%
import pandas as pd

train_data = pd.DataFrame(
    {"source accuracy": source_acc,
     "testing accuracy": test_acc,
     "target accuracy": test2_acc
    })
train_data.to_csv("./Model/DANN_Model/DANN/DANN_source_Resnet_RMS_1e-5_g5.csv")
