# %% [markdown]
# # Set Up

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# change to your working directory
#%cd "/content/drive/MyDrive/shared folder/Master_Thesis"
# %cd "/content/drive/MyDrive/shared_folder/Master_Thesis"
# Out:
# /content/drive/.shortcut-targets-by-id/1lHcON5EHJDerZlJ2mPUGsY4w6iFLBKs5/shared_folder/Master_Thesis

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPool2D, BatchNormalization, Dropout, Input, Activation, Reshape, GlobalMaxPooling2D, GlobalAveragePooling2D,  Add
from tensorflow.keras.applications import VGG16, InceptionV3, ResNet50, ResNet50V2, MobileNetV3Large
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.constraints import MinMaxNorm, MaxNorm
from sklearn.preprocessing import OneHotEncoder
import os ,random
import shutil
import sys
import matplotlib.pyplot as plt
import h5py
import pickle
from keras.preprocessing.image import load_img, img_to_array, array_to_img

# %%
print("GPU Available: ", tf.test.is_gpu_available())
print(tf.__version__)
# Out:
# WARNING:tensorflow:From <ipython-input-4-53c8631e9cc1>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# 2.8.0

# %%
# Original Dataset
Source_dir_train1 = "./Images/DANN/Source/LC25000_mix_data_128_train1.pkl"
Source_dir_train2 = "./Images/DANN/Source/LC25000_mix_data_128_train2.pkl"
Source_dir_train3 = "./Images/DANN/Source/LC25000_mix_data_128_train3.pkl"
Source_dir_train4 = "./Images/DANN/Source/LC25000_mix_data_128_train4.pkl"
Source_dir_train5 = "./Images/DANN/Source/LC25000_mix_data_128_train5.pkl"
Source_dir_test1 = "./Images/DANN/Source/LC25000_mix_data_128_test1.pkl"
Source_dir_test2 = "./Images/DANN/Source/LC25000_mix_data_128_test2.pkl"


Target_dir_train = os.path.abspath("./Images/DANN/Target/TCGA_mix_data_128_train.pkl")
Target_dir_test = os.path.abspath("./Images/DANN/Target/TCGA_mix_data_128_test.pkl")

# Cyclegan Dataset

Target_cyclegan_dir_train = os.path.abspath("./Images/DANN/Target_cyclegan/TCGA_cyclegan_mix_data_128_train.pkl")
Target_cyclegan_dir_test = os.path.abspath("./Images/DANN/Target_cyclegan/TCGA_cyclegan_mix_data_128_test.pkl")

# %%
BATCH_SIZE = 64
CHANNELS = 3
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
EPOCH = 5
learning_rate =1e-4

# %% [markdown]
# # Loading Dataset

# %% [markdown]
# ## configuration

# %%
#rescale
def convert(data_list):
    for i in range(len(data_list)): data_list[i]=data_list[i]/255

# %%
# Data Augmentation
def augment(image):
    image = np.array(image, dtype=np.float32)
    #image = (image / 255.0)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.15, seed=1)
    image = tf.image.random_hue(image, max_delta=0.09, seed=1)
    return image

def augment_1(image):
    image = np.array(image, dtype=np.float32)
    image = (image / 255.0)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.15, seed=1)
    image = tf.image.random_hue(image, max_delta=0.09, seed=1)
    return image

# process dataset
def data_augmentation(dataset):
    au=[]
    for file in dataset:
        file_au = augment(file)
        au.append(file_au)
    return au

# %% [markdown]
# ## LC25000 Dataset

# %%
# LC25000 Dataset
with open(os.path.abspath(Source_dir_train1), "rb") as f:
    LC25000_train1 = pickle.load(f)
with open(os.path.abspath(Source_dir_train2), "rb") as f:
    LC25000_train2 = pickle.load(f)
with open(os.path.abspath(Source_dir_train3), "rb") as f:
    LC25000_train3 = pickle.load(f)
with open(os.path.abspath(Source_dir_train4), "rb") as f:
    LC25000_train4 = pickle.load(f)
with open(os.path.abspath(Source_dir_train5), "rb") as f:
    LC25000_train5 = pickle.load(f)
with open(os.path.abspath(Source_dir_test1), "rb") as f:
    LC25000_test1 = pickle.load(f)
with open(os.path.abspath(Source_dir_test2), "rb") as f:
    LC25000_test2 = pickle.load(f)

# %%
LC25000_train_data = LC25000_train1['train'] + LC25000_train2['train'] + LC25000_train3['train'] + LC25000_train4['train'] + LC25000_train5['train']
LC25000_train_labels = np.concatenate((LC25000_train1['train_label'],LC25000_train2['train_label'],LC25000_train3['train_label'],LC25000_train4['train_label'],LC25000_train5['train_label']))
LC25000_test_data = LC25000_test1['test'] + LC25000_test2['test']
LC25000_test_labels = np.concatenate((LC25000_test1['test_label'],LC25000_test2['test_label']))

# %%
LC25000_train_lab = tf.one_hot(LC25000_train_labels, depth=3)
LC25000_test_lab = tf.one_hot(LC25000_test_labels, depth=3)

# %% [markdown]
# ### Data Augmentation Process

# %%
LC25000_train_data_au = data_augmentation(LC25000_train_data)
LC25000_test_data_au = data_augmentation(LC25000_test_data)

# %%
LC25000_train_data_au = np.array(LC25000_train_data_au, dtype=np.float32)
LC25000_test_data_au = np.array(LC25000_test_data_au, dtype=np.float32)

# %%
print("The shape of LC25000_train_data: ", LC25000_train_data_au.shape)
print("The shape of LC25000_train_labels: ", LC25000_train_labels.shape)
print("The shape of LC25000_test_data: ", LC25000_test_data_au.shape)
print("The shape of LC25000_test_labels: " ,LC25000_test_labels.shape)
# Out:
# The shape of LC25000_train_data:  (6400, 128, 128, 3)
# The shape of LC25000_train_labels:  (6400,)
# The shape of LC25000_test_data:  (1600, 128, 128, 3)
# The shape of LC25000_test_labels:  (1600,)

# %% [markdown]
# ## TCGA Dataset

# %%
# TCGA Dataset
with open(os.path.abspath(Target_dir_train), "rb") as f:
    TCGA_train = pickle.load(f)
with open(os.path.abspath(Target_dir_test), "rb") as f:
    TCGA_test = pickle.load(f)

# %%
TCGA_train_data = TCGA_train['train']
TCGA_train_labels = TCGA_train['train_label']
TCGA_test_data = TCGA_test['test']
TCGA_test_labels = TCGA_test['test_label']

# %%
TCGA_train_lab = tf.one_hot(TCGA_train_labels, depth=3)
TCGA_test_lab = tf.one_hot(TCGA_test_labels, depth=3)
TCGA_train_data = np.array(TCGA_train_data, dtype=np.float32)
TCGA_test_data = np.array(TCGA_test_data, dtype=np.float32)

# %%
print("The shape of TCGA_train_data: ", TCGA_train_data.shape)
print("The shape of TCGA_train_labels: ", TCGA_train_labels.shape)
print("The shape of TCGA_test_data: ", TCGA_test_data.shape)
print("The shape of TCGA_test_labels: " , TCGA_test_labels.shape)
# Out:
# The shape of TCGA_train_data:  (6400, 128, 128, 3)
# The shape of TCGA_train_labels:  (6400,)
# The shape of TCGA_test_data:  (6400, 128, 128, 3)
# The shape of TCGA_test_labels:  (6400,)

# %% [markdown]
# ## Datasets Visualization

# %%
# random show images
plt.subplots(1,2,figsize=(8,8))
ax1=plt.subplot(1,2,1)
sample1 = random.choice(LC25000_test_data_au)
img1 = array_to_img(sample1)
plt.title("LC25000_test_data_au")
plt.imshow(img1)
ax1=plt.subplot(1,2,2)
sample2 = random.choice(LC25000_test_data_au)
img2 = array_to_img(sample2)
plt.title("LC25000_test_data_au")
plt.imshow(img2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# random show images
plt.subplots(1,2,figsize=(10,10))
ax1=plt.subplot(1,2,1)
sample1 = random.choice(TCGA_train_data)
img1 = array_to_img(sample1)
plt.title("TCGA_train_data")
plt.imshow(img1)
ax1=plt.subplot(1,2,2)
sample2 = random.choice(TCGA_test_data)
img2 = array_to_img(sample2)
plt.title("TCGA_test_data")
plt.imshow(img2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # Domain Adaptation

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Feature Extractor - VGG16

# %%
vgg =  VGG16(include_top=False, input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, CHANNELS), pooling="max")

first_layer = vgg.get_layer('block4_pool')
inputs = Input(first_layer.output_shape[1:])

for layer in vgg.layers[vgg.layers.index(first_layer)+1:]:
    if layer.name == "block5_conv1":
        x = layer(inputs)
    else:
        x = layer(x)
    # x = layer(inputs)

first_blocks = Model(vgg.input, first_layer.output)
last_block = Model(inputs, x)

# %%
def load_vgg(path="./Model/DANN_Model/vgg_last_block.hdf5"):
    model = load_model(path)
    for i in range(len(model.layers)):
        if model.layers[i].__class__.__name__ == "BatchNormalization":
            model.layers[i].trainable = False
    return model

last_block.summary()
last_block.save("./Model/DANN_Model/vgg_last_block.hdf5")
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 8, 8, 512)]       0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
# =================================================================
# Total params: 7,079,424
# Trainable params: 7,079,424
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ### Extract the features

# %%
LC25000_train_data_au_ex = first_blocks.predict(preprocess_input(np.stack(LC25000_train_data_au)))
TCGA_train_data_ex = first_blocks.predict(preprocess_input(np.stack(TCGA_train_data)))
TCGA_test_data_ex = first_blocks.predict(preprocess_input(np.stack(TCGA_test_data)))

print("LC25000_train_data_au (source) shape: %s"%str(LC25000_train_data_au.shape))
print("TCGA_train_data (target) shape: %s"%str(TCGA_train_data.shape))
# Out:
# LC25000_train_data_au (source) shape: (6400, 128, 128, 3)
# TCGA_train_data (target) shape: (6400, 128, 128, 3)

# %% [markdown]
# ### Prepare Datasets

# %%
source_dataset = tf.data.Dataset.from_tensor_slices((LC25000_train_data_au_ex, LC25000_train_lab)).shuffle(1000).batch(BATCH_SIZE*2)
da_dataset = tf.data.Dataset.from_tensor_slices((LC25000_train_data_au_ex, LC25000_train_lab, TCGA_train_data_ex, TCGA_train_lab)).shuffle(1000).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((TCGA_test_data_ex, TCGA_test_lab)).shuffle(1000).batch(BATCH_SIZE*2) #Test Dataset over Target Domain
test_dataset2 = tf.data.Dataset.from_tensor_slices((TCGA_train_data_ex, TCGA_train_lab)).shuffle(1000).batch(BATCH_SIZE*2) #Test Dataset over Target (used for training)

# %% [markdown]
# ### VGG16 Model

# %%
feature_extractor_vgg = load_vgg()

class DANN_vgg(Model):
    def __init__(self):
        super().__init__()
        
        #Feature Extractor
        self.vgg_load = feature_extractor_vgg
        
        #Label Predictor
        self.max_norm = 0.5
        self.dropout= 0.5
        self.label_predictor_layer0 = Dense(1024, activation="relu",
                                            kernel_constraint=MaxNorm(self.max_norm),
                                            bias_constraint=MaxNorm(self.max_norm))
        self.label_predictor_layer1 = Dropout(self.dropout)
        self.label_predictor_layer2 = Dense(1024, activation="relu",
                                            kernel_constraint=MaxNorm(self.max_norm),
                                            bias_constraint=MaxNorm(self.max_norm))
        self.label_predictor_layer3 = Dropout(self.dropout)
        self.label_predictor_layer4 = Dense(3, activation=None)
        
        #Domain Predictor
        self.domain_predictor_layer0 = GradientReversalLayer()
        self.domain_predictor_layer1 = Dense(100, activation='relu')
        self.domain_predictor_layer2 = Dense(2, activation=None)
        
    def call(self, x, train=False, source_train=True, lamda=1.0):
        #Feature Extractor
        x = self.vgg_load(x)
        #print("x:", x)

        feature  = x
        
        #print("feature: ", feature)
        
        #Label Predictor
        if source_train is True:
            feature_slice = feature
            #print("feature_slice: ",feature_slice)
        else:
            feature_slice = tf.slice(feature, [0, 0], [feature.shape[0] // 2, -1])
            #print("feature_slice: ",feature_slice)
        
        lp_x = self.label_predictor_layer0(feature_slice)
        lp_x = self.label_predictor_layer1(lp_x)
        lp_x = self.label_predictor_layer2(lp_x)
        lp_x = self.label_predictor_layer3(lp_x)
        l_logits = self.label_predictor_layer4(lp_x)
        
        #Domain Predictor
        if source_train is True:
            return l_logits
        else:
            dp_x = self.domain_predictor_layer0(feature, lamda)    #GradientReversalLayer
            dp_x = self.domain_predictor_layer1(dp_x)
            d_logits = self.domain_predictor_layer2(dp_x)
            return l_logits, d_logits


#model = DANN_resnet()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ## Gradient Reversal Layer

# %%
@tf.custom_gradient
def gradient_reverse(x, lamda=1.0):
    y = tf.identity(x)
    
    def grad(dy):
        return lamda * -dy, None
    
    return y, grad


class GradientReversalLayer(tf.keras.layers.Layer):
    def __init__(self):
        super().__init__()
    
    def call(self, x, lamda=1.0):
        return gradient_reverse(x, lamda)

# %% [markdown]
# ## Define Loss and Optimizer

# %%
def loss_func(input_logits, target_labels):
    return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=input_logits, labels=target_labels))


def get_loss(l_logits, labels, d_logits=None, domain=None):
    if d_logits is None:
        return loss_func(l_logits, labels)
    else:        
        return loss_func(l_logits, labels) + loss_func(d_logits, domain)

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate= learning_rate,
    decay_steps=10000,
    decay_rate=0.9)

model_optimizer = tf.optimizers.Adam(learning_rate=lr_schedule)
#model_optimizer = tf.optimizers.SGD(learning_rate=lr_schedule)


#model_optimizer = tf.optimizers.Adam(learning_rate=1e-4)
# model_optimizer = tf.optimizers.SGD(learning_rate=1e-4)

# %% [markdown]
# ## Configuration of Training

# %%
domain_labels = np.vstack([np.tile([1., 0.], [BATCH_SIZE, 1]),
                           np.tile([0., 1.], [BATCH_SIZE, 1])])
domain_labels = domain_labels.astype('float32')

epoch_accuracy = tf.keras.metrics.CategoricalAccuracy()

source_acc = []  # Source Domain Accuracy while Source-only Training
da_acc = []      # Source Domain Accuracy while DA-training
test_acc = []    # Testing Dataset (Target Domain) Accuracy 
test2_acc = []   # Target Domain (used for Training) Accuracy

def reset_list():
    source_acc.clear() 
    da_acc.clear()
    test_acc.clear()
    test2_acc.clear()

# %%
@tf.function
def train_step_source(s_images, s_labels, lamda=1.0):
    images = s_images
    labels = s_labels
    
    with tf.GradientTape() as tape:
        output = model(images, train=True, source_train=True, lamda=lamda)
        
        model_loss = get_loss(output, labels)
        epoch_accuracy(output, labels)
        
    gradients_mdan = tape.gradient(model_loss, model.trainable_variables)
    model_optimizer.apply_gradients(zip(gradients_mdan, model.trainable_variables))


@tf.function
def train_step_da(s_images, s_labels, t_images=None, t_labels=None, lamda=1.0):
    images = tf.concat([s_images, t_images], 0)
    labels = s_labels
    
    with tf.GradientTape() as tape:
        output = model(images, train=True, source_train=False, lamda=lamda)
        
        model_loss = get_loss(output[0], labels, output[1], domain_labels)
        epoch_accuracy(output[0], labels)
        
    gradients_mdan = tape.gradient(model_loss, model.trainable_variables)
    model_optimizer.apply_gradients(zip(gradients_mdan, model.trainable_variables))


@tf.function
def test_step(t_images, t_labels):
    images = t_images
    labels = t_labels
    
    output = model(images, train=False, source_train=True)
    epoch_accuracy(output, labels)



def train(train_mode, epochs):
    
    if train_mode == 'source':
        dataset = source_dataset
        train_func = train_step_source
        acc_list = source_acc
    elif train_mode == 'domain-adaptation':
        dataset = da_dataset
        train_func = train_step_da
        acc_list = da_acc
    else:
        raise ValueError("Unknown training Mode")
    

    for epoch in range(epochs):
        p = float(epoch) / epochs
        lamda = 2 / (1 + np.exp(-gamma * p, dtype=np.float32)) - 1
        lamda = lamda.astype('float32')

        
        for batch in dataset:
            train_func(*batch, lamda=lamda)
        
        print("Training: Epoch {} :\t Source Accuracy : {:.3%}".format(epoch, epoch_accuracy.result()), end='  |  ')
        acc_list.append(epoch_accuracy.result())
        test()
        epoch_accuracy.reset_states()


def test():
    epoch_accuracy.reset_states()
    
    #Testing Dataset (Target Domain)

    for batch in test_dataset:
        test_step(*batch)
        
    print("Testing Accuracy : {:.3%}".format(epoch_accuracy.result()), end='  |  ')
    test_acc.append(epoch_accuracy.result())
    epoch_accuracy.reset_states()
    
    #Target Domain (used for Training)
    for batch in test_dataset2:
        test_step(*batch)
    
    print("Target Domain Accuracy : {:.3%}".format(epoch_accuracy.result()))
    test2_acc.append(epoch_accuracy.result())
    epoch_accuracy.reset_states()

# %% [markdown]
# # Training

# %% [markdown]
# ### domain-adaptation train : SGD=1e-6, gamma = 5

# %%
reset_list()

EPOCH= 100
model = DANN_vgg()
gamma = 5
learning_rate = 1e-6
model_optimizer = tf.optimizers.SGD(learning_rate=lr_schedule)
train('domain-adaptation', EPOCH)

#Plot Results
x_axis = [i for i in range(0, EPOCH)]

plt.title("Accuracy of DANN Model - Domain-adaptation Training")
plt.plot(x_axis, da_acc, label="source accuracy")
plt.plot(x_axis, test_acc, label="testing accuracy")
plt.plot(x_axis, test2_acc, label="target accuracy")
plt.legend()
# Out:
# Training: Epoch 0 :	 Source Accuracy : 88.219%  |  Testing Accuracy : 47.344%  |  Target Domain Accuracy : 46.672%
# Training: Epoch 1 :	 Source Accuracy : 94.734%  |  Testing Accuracy : 45.984%  |  Target Domain Accuracy : 45.969%
# Training: Epoch 2 :	 Source Accuracy : 96.031%  |  Testing Accuracy : 44.688%  |  Target Domain Accuracy : 44.359%
# Training: Epoch 3 :	 Source Accuracy : 96.359%  |  Testing Accuracy : 43.969%  |  Target Domain Accuracy : 43.172%
# Training: Epoch 4 :	 Source Accuracy : 96.922%  |  Testing Accuracy : 44.813%  |  Target Domain Accuracy : 44.469%
# Training: Epoch 5 :	 Source Accuracy : 97.078%  |  Testing Accuracy : 45.437%  |  Target Domain Accuracy : 44.703%
# Training: Epoch 6 :	 Source Accuracy : 96.203%  |  Testing Accuracy : 42.234%  |  Target Domain Accuracy : 41.453%
# Training: Epoch 7 :	 Source Accuracy : 91.969%  |  Testing Accuracy : 47.250%  |  Target Domain Accuracy : 47.578%
# Training: Epoch 8 :	 Source Accuracy : 88.625%  |  Testing Accuracy : 33.953%  |  Target Domain Accuracy : 34.062%
# Training: Epoch 9 :	 Source Accuracy : 88.781%  |  Testing Accuracy : 42.063%  |  Target Domain Accuracy : 43.047%
# Training: Epoch 10 :	 Source Accuracy : 90.281%  |  Testing Accuracy : 25.734%  |  Target Domain Accuracy : 25.109%
# Training: Epoch 11 :	 Source Accuracy : 94.969%  |  Testing Accuracy : 33.047%  |  Target Domain Accuracy : 32.672%
# Training: Epoch 12 :	 Source Accuracy : 93.609%  |  Testing Accuracy : 45.625%  |  Target Domain Accuracy : 45.609%
# Training: Epoch 13 :	 Source Accuracy : 95.047%  |  Testing Accuracy : 43.781%  |  Target Domain Accuracy : 44.031%
# Training: Epoch 14 :	 Source Accuracy : 91.859%  |  Testing Accuracy : 41.578%  |  Target Domain Accuracy : 42.063%
# Training: Epoch 15 :	 Source Accuracy : 91.891%  |  Testing Accuracy : 32.078%  |  Target Domain Accuracy : 32.719%
# Training: Epoch 16 :	 Source Accuracy : 92.797%  |  Testing Accuracy : 47.859%  |  Target Domain Accuracy : 47.547%
# Training: Epoch 17 :	 Source Accuracy : 92.000%  |  Testing Accuracy : 34.344%  |  Target Domain Accuracy : 35.063%
# Training: Epoch 18 :	 Source Accuracy : 91.531%  |  Testing Accuracy : 46.453%  |  Target Domain Accuracy : 46.422%
# Training: Epoch 19 :	 Source Accuracy : 92.703%  |  Testing Accuracy : 40.406%  |  Target Domain Accuracy : 40.688%
# Training: Epoch 20 :	 Source Accuracy : 91.312%  |  Testing Accuracy : 44.469%  |  Target Domain Accuracy : 44.422%
# Training: Epoch 21 :	 Source Accuracy : 92.047%  |  Testing Accuracy : 34.422%  |  Target Domain Accuracy : 34.406%
# Training: Epoch 22 :	 Source Accuracy : 94.578%  |  Testing Accuracy : 27.156%  |  Target Domain Accuracy : 25.641%
# Training: Epoch 23 :	 Source Accuracy : 93.500%  |  Testing Accuracy : 41.594%  |  Target Domain Accuracy : 41.672%
# Training: Epoch 24 :	 Source Accuracy : 91.969%  |  Testing Accuracy : 41.969%  |  Target Domain Accuracy : 41.906%
# Training: Epoch 25 :	 Source Accuracy : 93.250%  |  Testing Accuracy : 37.734%  |  Target Domain Accuracy : 38.438%
# Training: Epoch 26 :	 Source Accuracy : 89.188%  |  Testing Accuracy : 50.016%  |  Target Domain Accuracy : 50.000%
# Training: Epoch 27 :	 Source Accuracy : 89.281%  |  Testing Accuracy : 45.312%  |  Target Domain Accuracy : 45.219%
# Training: Epoch 28 :	 Source Accuracy : 87.937%  |  Testing Accuracy : 32.297%  |  Target Domain Accuracy : 32.047%
# Training: Epoch 29 :	 Source Accuracy : 93.547%  |  Testing Accuracy : 49.203%  |  Target Domain Accuracy : 49.156%
# Training: Epoch 30 :	 Source Accuracy : 94.328%  |  Testing Accuracy : 42.844%  |  Target Domain Accuracy : 42.969%
# Training: Epoch 31 :	 Source Accuracy : 91.766%  |  Testing Accuracy : 37.875%  |  Target Domain Accuracy : 38.219%
# Training: Epoch 32 :	 Source Accuracy : 88.422%  |  Testing Accuracy : 35.969%  |  Target Domain Accuracy : 35.969%
# Training: Epoch 33 :	 Source Accuracy : 95.203%  |  Testing Accuracy : 37.250%  |  Target Domain Accuracy : 37.344%
# Training: Epoch 34 :	 Source Accuracy : 94.937%  |  Testing Accuracy : 44.406%  |  Target Domain Accuracy : 44.063%
# Training: Epoch 35 :	 Source Accuracy : 94.813%  |  Testing Accuracy : 45.656%  |  Target Domain Accuracy : 45.172%
# Training: Epoch 36 :	 Source Accuracy : 95.891%  |  Testing Accuracy : 41.516%  |  Target Domain Accuracy : 41.531%
# Training: Epoch 37 :	 Source Accuracy : 95.609%  |  Testing Accuracy : 42.016%  |  Target Domain Accuracy : 41.875%
# Training: Epoch 38 :	 Source Accuracy : 96.234%  |  Testing Accuracy : 41.078%  |  Target Domain Accuracy : 41.359%
# Training: Epoch 39 :	 Source Accuracy : 94.984%  |  Testing Accuracy : 37.594%  |  Target Domain Accuracy : 38.031%
# Training: Epoch 40 :	 Source Accuracy : 96.656%  |  Testing Accuracy : 39.687%  |  Target Domain Accuracy : 40.219%
# Training: Epoch 41 :	 Source Accuracy : 96.562%  |  Testing Accuracy : 41.891%  |  Target Domain Accuracy : 42.109%
# Training: Epoch 42 :	 Source Accuracy : 95.656%  |  Testing Accuracy : 39.531%  |  Target Domain Accuracy : 39.828%
# Training: Epoch 43 :	 Source Accuracy : 97.062%  |  Testing Accuracy : 39.250%  |  Target Domain Accuracy : 39.484%
# Training: Epoch 44 :	 Source Accuracy : 96.906%  |  Testing Accuracy : 38.203%  |  Target Domain Accuracy : 38.406%
# Training: Epoch 45 :	 Source Accuracy : 97.188%  |  Testing Accuracy : 36.812%  |  Target Domain Accuracy : 37.500%
# Training: Epoch 46 :	 Source Accuracy : 97.219%  |  Testing Accuracy : 35.984%  |  Target Domain Accuracy : 36.031%
# Training: Epoch 47 :	 Source Accuracy : 97.766%  |  Testing Accuracy : 35.984%  |  Target Domain Accuracy : 36.562%
# Training: Epoch 48 :	 Source Accuracy : 97.406%  |  Testing Accuracy : 36.078%  |  Target Domain Accuracy : 36.656%
# Training: Epoch 49 :	 Source Accuracy : 97.359%  |  Testing Accuracy : 38.234%  |  Target Domain Accuracy : 38.734%
# Training: Epoch 50 :	 Source Accuracy : 94.359%  |  Testing Accuracy : 39.016%  |  Target Domain Accuracy : 38.922%
# Training: Epoch 51 :	 Source Accuracy : 92.281%  |  Testing Accuracy : 40.625%  |  Target Domain Accuracy : 40.813%
# Training: Epoch 52 :	 Source Accuracy : 95.516%  |  Testing Accuracy : 38.906%  |  Target Domain Accuracy : 39.312%
# Training: Epoch 53 :	 Source Accuracy : 97.531%  |  Testing Accuracy : 36.312%  |  Target Domain Accuracy : 35.656%
# Training: Epoch 54 :	 Source Accuracy : 97.125%  |  Testing Accuracy : 44.406%  |  Target Domain Accuracy : 44.266%
# Training: Epoch 55 :	 Source Accuracy : 97.078%  |  Testing Accuracy : 35.734%  |  Target Domain Accuracy : 36.156%
# Training: Epoch 56 :	 Source Accuracy : 97.172%  |  Testing Accuracy : 37.766%  |  Target Domain Accuracy : 37.359%
# Training: Epoch 57 :	 Source Accuracy : 97.188%  |  Testing Accuracy : 38.125%  |  Target Domain Accuracy : 38.313%
# Training: Epoch 58 :	 Source Accuracy : 97.391%  |  Testing Accuracy : 39.172%  |  Target Domain Accuracy : 39.531%
# Training: Epoch 59 :	 Source Accuracy : 97.000%  |  Testing Accuracy : 39.484%  |  Target Domain Accuracy : 39.531%
# Training: Epoch 60 :	 Source Accuracy : 96.625%  |  Testing Accuracy : 39.281%  |  Target Domain Accuracy : 39.609%
# Training: Epoch 61 :	 Source Accuracy : 97.812%  |  Testing Accuracy : 38.766%  |  Target Domain Accuracy : 38.594%
# Training: Epoch 62 :	 Source Accuracy : 97.922%  |  Testing Accuracy : 40.125%  |  Target Domain Accuracy : 40.312%
# Training: Epoch 63 :	 Source Accuracy : 97.891%  |  Testing Accuracy : 40.500%  |  Target Domain Accuracy : 40.437%
# Training: Epoch 64 :	 Source Accuracy : 97.406%  |  Testing Accuracy : 41.359%  |  Target Domain Accuracy : 41.125%
# Training: Epoch 65 :	 Source Accuracy : 97.688%  |  Testing Accuracy : 40.109%  |  Target Domain Accuracy : 39.937%
# Training: Epoch 66 :	 Source Accuracy : 97.891%  |  Testing Accuracy : 39.578%  |  Target Domain Accuracy : 39.437%
# Training: Epoch 67 :	 Source Accuracy : 97.984%  |  Testing Accuracy : 38.625%  |  Target Domain Accuracy : 39.203%
# Training: Epoch 68 :	 Source Accuracy : 97.938%  |  Testing Accuracy : 39.812%  |  Target Domain Accuracy : 39.750%
# Training: Epoch 69 :	 Source Accuracy : 97.828%  |  Testing Accuracy : 41.250%  |  Target Domain Accuracy : 40.328%
# Training: Epoch 70 :	 Source Accuracy : 98.156%  |  Testing Accuracy : 39.547%  |  Target Domain Accuracy : 38.734%
# Training: Epoch 71 :	 Source Accuracy : 97.969%  |  Testing Accuracy : 39.453%  |  Target Domain Accuracy : 39.578%
# Training: Epoch 72 :	 Source Accuracy : 97.609%  |  Testing Accuracy : 39.953%  |  Target Domain Accuracy : 39.219%
# Training: Epoch 73 :	 Source Accuracy : 98.078%  |  Testing Accuracy : 39.031%  |  Target Domain Accuracy : 39.328%
# Training: Epoch 74 :	 Source Accuracy : 97.859%  |  Testing Accuracy : 40.625%  |  Target Domain Accuracy : 39.609%
# Training: Epoch 75 :	 Source Accuracy : 98.266%  |  Testing Accuracy : 39.203%  |  Target Domain Accuracy : 38.766%
# Training: Epoch 76 :	 Source Accuracy : 98.328%  |  Testing Accuracy : 40.562%  |  Target Domain Accuracy : 39.484%
# Training: Epoch 77 :	 Source Accuracy : 98.281%  |  Testing Accuracy : 39.719%  |  Target Domain Accuracy : 39.531%
# Training: Epoch 78 :	 Source Accuracy : 98.391%  |  Testing Accuracy : 42.312%  |  Target Domain Accuracy : 41.719%
# Training: Epoch 79 :	 Source Accuracy : 97.938%  |  Testing Accuracy : 40.531%  |  Target Domain Accuracy : 39.859%
# Training: Epoch 80 :	 Source Accuracy : 98.109%  |  Testing Accuracy : 40.187%  |  Target Domain Accuracy : 39.203%
# Training: Epoch 81 :	 Source Accuracy : 98.344%  |  Testing Accuracy : 41.188%  |  Target Domain Accuracy : 40.203%
# Training: Epoch 82 :	 Source Accuracy : 98.469%  |  Testing Accuracy : 42.281%  |  Target Domain Accuracy : 41.188%
# Training: Epoch 83 :	 Source Accuracy : 98.328%  |  Testing Accuracy : 39.937%  |  Target Domain Accuracy : 39.094%
# Training: Epoch 84 :	 Source Accuracy : 98.125%  |  Testing Accuracy : 42.000%  |  Target Domain Accuracy : 41.000%
# Training: Epoch 85 :	 Source Accuracy : 98.250%  |  Testing Accuracy : 39.859%  |  Target Domain Accuracy : 39.031%
# Training: Epoch 86 :	 Source Accuracy : 98.609%  |  Testing Accuracy : 40.844%  |  Target Domain Accuracy : 40.047%
# Training: Epoch 87 :	 Source Accuracy : 98.406%  |  Testing Accuracy : 40.828%  |  Target Domain Accuracy : 39.703%
# Training: Epoch 88 :	 Source Accuracy : 98.125%  |  Testing Accuracy : 39.234%  |  Target Domain Accuracy : 38.297%
# Training: Epoch 89 :	 Source Accuracy : 98.547%  |  Testing Accuracy : 40.547%  |  Target Domain Accuracy : 39.797%
# Training: Epoch 90 :	 Source Accuracy : 98.516%  |  Testing Accuracy : 40.172%  |  Target Domain Accuracy : 39.578%
# Training: Epoch 91 :	 Source Accuracy : 98.391%  |  Testing Accuracy : 39.703%  |  Target Domain Accuracy : 39.172%
# Training: Epoch 92 :	 Source Accuracy : 98.344%  |  Testing Accuracy : 40.609%  |  Target Domain Accuracy : 40.031%
# Training: Epoch 93 :	 Source Accuracy : 98.516%  |  Testing Accuracy : 39.953%  |  Target Domain Accuracy : 39.375%
# Training: Epoch 94 :	 Source Accuracy : 98.625%  |  Testing Accuracy : 40.469%  |  Target Domain Accuracy : 40.203%
# Training: Epoch 95 :	 Source Accuracy : 98.172%  |  Testing Accuracy : 39.984%  |  Target Domain Accuracy : 39.578%
# Training: Epoch 96 :	 Source Accuracy : 98.547%  |  Testing Accuracy : 39.609%  |  Target Domain Accuracy : 39.031%
# Training: Epoch 97 :	 Source Accuracy : 98.359%  |  Testing Accuracy : 40.469%  |  Target Domain Accuracy : 39.578%
# Training: Epoch 98 :	 Source Accuracy : 98.438%  |  Testing Accuracy : 40.375%  |  Target Domain Accuracy : 39.469%
# Training: Epoch 99 :	 Source Accuracy : 98.547%  |  Testing Accuracy : 40.922%  |  Target Domain Accuracy : 39.953%

# %%
import pandas as pd

train_data = pd.DataFrame(
    {"source accuracy": da_acc,
     "testing accuracy": test_acc,
     "target accuracy": test2_acc
    })
train_data.to_csv("./Model/DANN_Model/DANN_128/DANN_VGG__128SGD_1e-6_g5_AU.csv")

# %% [markdown]
# ### source train : SGD=1e-6

# %%
reset_list()

EPOCH= 100
model = DANN_vgg()
gamma = 5
learning_rate = 1e-6
model_optimizer = tf.optimizers.SGD(learning_rate=lr_schedule)
# model_optimizer = tf.optimizers.RMSprop(learning_rate=1e-5)
train('source', EPOCH)

#Plot Results
x_axis = [i for i in range(0, EPOCH)]

plt.title("Accuracy of DANN Model - Source-oonly Training")
plt.plot(x_axis, source_acc, label="source accuracy")
plt.plot(x_axis, test_acc, label="testing accuracy")
plt.plot(x_axis, test2_acc, label="target accuracy")
plt.legend()
# Out:
# Training: Epoch 0 :	 Source Accuracy : 85.062%  |  Testing Accuracy : 35.313%  |  Target Domain Accuracy : 33.906%
# Training: Epoch 1 :	 Source Accuracy : 90.812%  |  Testing Accuracy : 36.812%  |  Target Domain Accuracy : 34.906%
# Training: Epoch 2 :	 Source Accuracy : 92.641%  |  Testing Accuracy : 37.141%  |  Target Domain Accuracy : 36.016%
# Training: Epoch 3 :	 Source Accuracy : 94.000%  |  Testing Accuracy : 38.031%  |  Target Domain Accuracy : 37.078%
# Training: Epoch 4 :	 Source Accuracy : 93.891%  |  Testing Accuracy : 37.031%  |  Target Domain Accuracy : 36.187%
# Training: Epoch 5 :	 Source Accuracy : 94.875%  |  Testing Accuracy : 37.000%  |  Target Domain Accuracy : 36.328%
# Training: Epoch 6 :	 Source Accuracy : 95.187%  |  Testing Accuracy : 37.734%  |  Target Domain Accuracy : 36.906%
# Training: Epoch 7 :	 Source Accuracy : 95.312%  |  Testing Accuracy : 37.891%  |  Target Domain Accuracy : 36.937%
# Training: Epoch 8 :	 Source Accuracy : 95.781%  |  Testing Accuracy : 37.625%  |  Target Domain Accuracy : 36.703%
# Training: Epoch 9 :	 Source Accuracy : 96.125%  |  Testing Accuracy : 37.922%  |  Target Domain Accuracy : 36.766%
# Training: Epoch 10 :	 Source Accuracy : 96.453%  |  Testing Accuracy : 38.672%  |  Target Domain Accuracy : 37.078%
# Training: Epoch 11 :	 Source Accuracy : 96.203%  |  Testing Accuracy : 38.547%  |  Target Domain Accuracy : 37.156%
# Training: Epoch 12 :	 Source Accuracy : 96.312%  |  Testing Accuracy : 38.797%  |  Target Domain Accuracy : 37.437%
# Training: Epoch 13 :	 Source Accuracy : 96.688%  |  Testing Accuracy : 38.797%  |  Target Domain Accuracy : 37.437%
# Training: Epoch 14 :	 Source Accuracy : 96.875%  |  Testing Accuracy : 38.219%  |  Target Domain Accuracy : 37.031%
# Training: Epoch 15 :	 Source Accuracy : 96.922%  |  Testing Accuracy : 39.156%  |  Target Domain Accuracy : 37.781%
# Training: Epoch 16 :	 Source Accuracy : 96.969%  |  Testing Accuracy : 38.594%  |  Target Domain Accuracy : 37.437%
# Training: Epoch 17 :	 Source Accuracy : 97.344%  |  Testing Accuracy : 39.187%  |  Target Domain Accuracy : 37.766%
# Training: Epoch 18 :	 Source Accuracy : 97.281%  |  Testing Accuracy : 38.641%  |  Target Domain Accuracy : 37.359%
# Training: Epoch 19 :	 Source Accuracy : 97.172%  |  Testing Accuracy : 38.219%  |  Target Domain Accuracy : 37.234%
# Training: Epoch 20 :	 Source Accuracy : 97.656%  |  Testing Accuracy : 38.938%  |  Target Domain Accuracy : 37.766%
# Training: Epoch 21 :	 Source Accuracy : 97.500%  |  Testing Accuracy : 38.328%  |  Target Domain Accuracy : 37.328%
# Training: Epoch 22 :	 Source Accuracy : 97.609%  |  Testing Accuracy : 39.000%  |  Target Domain Accuracy : 37.875%
# Training: Epoch 23 :	 Source Accuracy : 97.562%  |  Testing Accuracy : 38.625%  |  Target Domain Accuracy : 37.641%
# Training: Epoch 24 :	 Source Accuracy : 97.797%  |  Testing Accuracy : 38.813%  |  Target Domain Accuracy : 37.734%
# Training: Epoch 25 :	 Source Accuracy : 97.703%  |  Testing Accuracy : 38.688%  |  Target Domain Accuracy : 37.750%
# Training: Epoch 26 :	 Source Accuracy : 97.969%  |  Testing Accuracy : 38.484%  |  Target Domain Accuracy : 37.578%
# Training: Epoch 27 :	 Source Accuracy : 97.781%  |  Testing Accuracy : 38.516%  |  Target Domain Accuracy : 37.828%
# Training: Epoch 28 :	 Source Accuracy : 97.969%  |  Testing Accuracy : 38.281%  |  Target Domain Accuracy : 37.563%
# Training: Epoch 29 :	 Source Accuracy : 97.953%  |  Testing Accuracy : 38.766%  |  Target Domain Accuracy : 37.891%
# Training: Epoch 30 :	 Source Accuracy : 98.016%  |  Testing Accuracy : 38.516%  |  Target Domain Accuracy : 37.875%
# Training: Epoch 31 :	 Source Accuracy : 98.016%  |  Testing Accuracy : 38.500%  |  Target Domain Accuracy : 37.797%
# Training: Epoch 32 :	 Source Accuracy : 98.234%  |  Testing Accuracy : 38.453%  |  Target Domain Accuracy : 37.703%
# Training: Epoch 33 :	 Source Accuracy : 98.172%  |  Testing Accuracy : 38.453%  |  Target Domain Accuracy : 37.922%
# Training: Epoch 34 :	 Source Accuracy : 98.281%  |  Testing Accuracy : 38.375%  |  Target Domain Accuracy : 37.797%
# Training: Epoch 35 :	 Source Accuracy : 98.156%  |  Testing Accuracy : 38.344%  |  Target Domain Accuracy : 37.875%
# Training: Epoch 36 :	 Source Accuracy : 98.172%  |  Testing Accuracy : 38.281%  |  Target Domain Accuracy : 37.797%
# Training: Epoch 37 :	 Source Accuracy : 98.375%  |  Testing Accuracy : 38.422%  |  Target Domain Accuracy : 37.984%
# Training: Epoch 38 :	 Source Accuracy : 98.422%  |  Testing Accuracy : 38.375%  |  Target Domain Accuracy : 38.141%
# Training: Epoch 39 :	 Source Accuracy : 98.219%  |  Testing Accuracy : 38.188%  |  Target Domain Accuracy : 37.891%
# Training: Epoch 40 :	 Source Accuracy : 98.609%  |  Testing Accuracy : 38.750%  |  Target Domain Accuracy : 38.266%
# Training: Epoch 41 :	 Source Accuracy : 98.422%  |  Testing Accuracy : 38.422%  |  Target Domain Accuracy : 38.063%
# Training: Epoch 42 :	 Source Accuracy : 98.578%  |  Testing Accuracy : 38.406%  |  Target Domain Accuracy : 38.109%
# Training: Epoch 43 :	 Source Accuracy : 98.609%  |  Testing Accuracy : 38.547%  |  Target Domain Accuracy : 38.297%
# Training: Epoch 44 :	 Source Accuracy : 98.609%  |  Testing Accuracy : 38.297%  |  Target Domain Accuracy : 38.031%
# Training: Epoch 45 :	 Source Accuracy : 98.719%  |  Testing Accuracy : 38.266%  |  Target Domain Accuracy : 37.922%
# Training: Epoch 46 :	 Source Accuracy : 98.641%  |  Testing Accuracy : 38.438%  |  Target Domain Accuracy : 38.250%
# Training: Epoch 47 :	 Source Accuracy : 98.797%  |  Testing Accuracy : 38.484%  |  Target Domain Accuracy : 38.250%
# Training: Epoch 48 :	 Source Accuracy : 98.828%  |  Testing Accuracy : 38.078%  |  Target Domain Accuracy : 37.703%
# Training: Epoch 49 :	 Source Accuracy : 98.859%  |  Testing Accuracy : 38.297%  |  Target Domain Accuracy : 37.938%
# Training: Epoch 50 :	 Source Accuracy : 98.859%  |  Testing Accuracy : 38.359%  |  Target Domain Accuracy : 38.125%
# Training: Epoch 51 :	 Source Accuracy : 98.813%  |  Testing Accuracy : 37.859%  |  Target Domain Accuracy : 37.500%
# Training: Epoch 52 :	 Source Accuracy : 99.016%  |  Testing Accuracy : 38.516%  |  Target Domain Accuracy : 38.281%
# Training: Epoch 53 :	 Source Accuracy : 99.031%  |  Testing Accuracy : 38.328%  |  Target Domain Accuracy : 38.188%
# Training: Epoch 54 :	 Source Accuracy : 98.891%  |  Testing Accuracy : 38.328%  |  Target Domain Accuracy : 37.938%
# Training: Epoch 55 :	 Source Accuracy : 99.031%  |  Testing Accuracy : 38.078%  |  Target Domain Accuracy : 37.859%
# Training: Epoch 56 :	 Source Accuracy : 98.953%  |  Testing Accuracy : 38.172%  |  Target Domain Accuracy : 37.984%
# Training: Epoch 57 :	 Source Accuracy : 98.937%  |  Testing Accuracy : 38.141%  |  Target Domain Accuracy : 37.969%
# Training: Epoch 58 :	 Source Accuracy : 99.047%  |  Testing Accuracy : 38.125%  |  Target Domain Accuracy : 38.000%
# Training: Epoch 59 :	 Source Accuracy : 98.906%  |  Testing Accuracy : 37.719%  |  Target Domain Accuracy : 37.453%
# Training: Epoch 60 :	 Source Accuracy : 99.141%  |  Testing Accuracy : 37.906%  |  Target Domain Accuracy : 37.750%
# Training: Epoch 61 :	 Source Accuracy : 99.094%  |  Testing Accuracy : 37.969%  |  Target Domain Accuracy : 37.688%
# Training: Epoch 62 :	 Source Accuracy : 99.172%  |  Testing Accuracy : 38.063%  |  Target Domain Accuracy : 37.906%
# Training: Epoch 63 :	 Source Accuracy : 99.219%  |  Testing Accuracy : 38.078%  |  Target Domain Accuracy : 38.016%
# Training: Epoch 64 :	 Source Accuracy : 99.219%  |  Testing Accuracy : 38.109%  |  Target Domain Accuracy : 38.078%
# Training: Epoch 65 :	 Source Accuracy : 99.313%  |  Testing Accuracy : 37.969%  |  Target Domain Accuracy : 37.859%
# Training: Epoch 66 :	 Source Accuracy : 99.281%  |  Testing Accuracy : 37.828%  |  Target Domain Accuracy : 37.625%
# Training: Epoch 67 :	 Source Accuracy : 99.344%  |  Testing Accuracy : 37.891%  |  Target Domain Accuracy : 37.719%
# Training: Epoch 68 :	 Source Accuracy : 99.078%  |  Testing Accuracy : 37.953%  |  Target Domain Accuracy : 37.734%
# Training: Epoch 69 :	 Source Accuracy : 99.391%  |  Testing Accuracy : 37.922%  |  Target Domain Accuracy : 37.688%
# Training: Epoch 70 :	 Source Accuracy : 99.250%  |  Testing Accuracy : 38.000%  |  Target Domain Accuracy : 37.750%
# Training: Epoch 71 :	 Source Accuracy : 99.219%  |  Testing Accuracy : 38.094%  |  Target Domain Accuracy : 37.844%
# Training: Epoch 72 :	 Source Accuracy : 99.328%  |  Testing Accuracy : 37.922%  |  Target Domain Accuracy : 37.688%
# Training: Epoch 73 :	 Source Accuracy : 99.391%  |  Testing Accuracy : 37.781%  |  Target Domain Accuracy : 37.594%
# Training: Epoch 74 :	 Source Accuracy : 99.391%  |  Testing Accuracy : 38.016%  |  Target Domain Accuracy : 37.781%
# Training: Epoch 75 :	 Source Accuracy : 99.437%  |  Testing Accuracy : 37.953%  |  Target Domain Accuracy : 37.703%
# Training: Epoch 76 :	 Source Accuracy : 99.406%  |  Testing Accuracy : 37.781%  |  Target Domain Accuracy : 37.484%
# Training: Epoch 77 :	 Source Accuracy : 99.406%  |  Testing Accuracy : 38.031%  |  Target Domain Accuracy : 37.734%
# Training: Epoch 78 :	 Source Accuracy : 99.406%  |  Testing Accuracy : 37.750%  |  Target Domain Accuracy : 37.563%
# Training: Epoch 79 :	 Source Accuracy : 99.484%  |  Testing Accuracy : 37.859%  |  Target Domain Accuracy : 37.625%
# Training: Epoch 80 :	 Source Accuracy : 99.359%  |  Testing Accuracy : 37.781%  |  Target Domain Accuracy : 37.609%
# Training: Epoch 81 :	 Source Accuracy : 99.422%  |  Testing Accuracy : 37.609%  |  Target Domain Accuracy : 37.375%
# Training: Epoch 82 :	 Source Accuracy : 99.531%  |  Testing Accuracy : 37.734%  |  Target Domain Accuracy : 37.516%
# Training: Epoch 83 :	 Source Accuracy : 99.625%  |  Testing Accuracy : 37.891%  |  Target Domain Accuracy : 37.625%
# Training: Epoch 84 :	 Source Accuracy : 99.563%  |  Testing Accuracy : 37.750%  |  Target Domain Accuracy : 37.563%
# Training: Epoch 85 :	 Source Accuracy : 99.547%  |  Testing Accuracy : 37.906%  |  Target Domain Accuracy : 37.547%
# Training: Epoch 86 :	 Source Accuracy : 99.563%  |  Testing Accuracy : 37.844%  |  Target Domain Accuracy : 37.578%
# Training: Epoch 87 :	 Source Accuracy : 99.469%  |  Testing Accuracy : 37.844%  |  Target Domain Accuracy : 37.641%
# Training: Epoch 88 :	 Source Accuracy : 99.484%  |  Testing Accuracy : 37.688%  |  Target Domain Accuracy : 37.563%
# Training: Epoch 89 :	 Source Accuracy : 99.594%  |  Testing Accuracy : 37.828%  |  Target Domain Accuracy : 37.625%
# Training: Epoch 90 :	 Source Accuracy : 99.594%  |  Testing Accuracy : 37.656%  |  Target Domain Accuracy : 37.547%
# Training: Epoch 91 :	 Source Accuracy : 99.563%  |  Testing Accuracy : 37.766%  |  Target Domain Accuracy : 37.563%
# Training: Epoch 92 :	 Source Accuracy : 99.625%  |  Testing Accuracy : 38.031%  |  Target Domain Accuracy : 37.688%
# Training: Epoch 93 :	 Source Accuracy : 99.609%  |  Testing Accuracy : 37.672%  |  Target Domain Accuracy : 37.500%
# Training: Epoch 94 :	 Source Accuracy : 99.687%  |  Testing Accuracy : 37.672%  |  Target Domain Accuracy : 37.531%
# Training: Epoch 95 :	 Source Accuracy : 99.609%  |  Testing Accuracy : 38.031%  |  Target Domain Accuracy : 37.719%
# Training: Epoch 96 :	 Source Accuracy : 99.656%  |  Testing Accuracy : 37.781%  |  Target Domain Accuracy : 37.563%
# Training: Epoch 97 :	 Source Accuracy : 99.797%  |  Testing Accuracy : 37.813%  |  Target Domain Accuracy : 37.625%
# Training: Epoch 98 :	 Source Accuracy : 99.625%  |  Testing Accuracy : 37.844%  |  Target Domain Accuracy : 37.656%
# Training: Epoch 99 :	 Source Accuracy : 99.641%  |  Testing Accuracy : 37.734%  |  Target Domain Accuracy : 37.641%

# %%
import pandas as pd

train_data = pd.DataFrame(
    {"source accuracy": source_acc,
     "testing accuracy": test_acc,
     "target accuracy": test2_acc
    })
train_data.to_csv("./Model/DANN_Model/DANN_128/DANN_source_VGG_128_SGD_1e-6_g5_AU.csv")
