# %% [markdown]
# # Set Up

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# change to your working directory
#%cd "/content/drive/MyDrive/shared folder/Master_Thesis"
# %cd "/content/drive/MyDrive/shared_folder/Master_Thesis"
# Out:
# /content/drive/.shortcut-targets-by-id/1lHcON5EHJDerZlJ2mPUGsY4w6iFLBKs5/shared_folder/Master_Thesis

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPool2D, BatchNormalization, Dropout, Input, Activation, Reshape, GlobalMaxPooling2D, GlobalAveragePooling2D,  Add
from tensorflow.keras.applications import VGG16, InceptionV3, ResNet50, ResNet50V2, MobileNetV3Large
from tensorflow.keras.applications.resnet50 import preprocess_input, ResNet50
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.constraints import MinMaxNorm, MaxNorm
from sklearn.preprocessing import OneHotEncoder
import os ,random
import shutil
import sys
import matplotlib.pyplot as plt
import h5py
import pickle
from keras.preprocessing.image import load_img, img_to_array, array_to_img

# %%
print("GPU Available: ", tf.test.is_gpu_available())
print(tf.__version__)
# Out:
# WARNING:tensorflow:From <ipython-input-4-53c8631e9cc1>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# 2.8.0

# %%
# Original Dataset
Source_dir_train1 = "./Images/DANN/Source/LC25000_mix_data_128_train1.pkl"
Source_dir_train2 = "./Images/DANN/Source/LC25000_mix_data_128_train2.pkl"
Source_dir_train3 = "./Images/DANN/Source/LC25000_mix_data_128_train3.pkl"
Source_dir_train4 = "./Images/DANN/Source/LC25000_mix_data_128_train4.pkl"
Source_dir_train5 = "./Images/DANN/Source/LC25000_mix_data_128_train5.pkl"
Source_dir_test1 = "./Images/DANN/Source/LC25000_mix_data_128_test1.pkl"
Source_dir_test2 = "./Images/DANN/Source/LC25000_mix_data_128_test2.pkl"


Target_dir_train = os.path.abspath("./Images/DANN/Target/TCGA_mix_data_128_train.pkl")
Target_dir_test = os.path.abspath("./Images/DANN/Target/TCGA_mix_data_128_test.pkl")
# Cyclegan Dataset

Target_cyclegan_dir_train = os.path.abspath("./Images/DANN/Target_cyclegan/TCGA_cyclegan_mix_data_128_train.pkl")
Target_cyclegan_dir_test = os.path.abspath("./Images/DANN/Target_cyclegan/TCGA_cyclegan_mix_data_128_test.pkl")

# %%
BATCH_SIZE = 64
CHANNELS = 3
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
EPOCH = 5
learning_rate =1e-4

# %% [markdown]
# # Loading Dataset

# %% [markdown]
# ## LC25000 Dataset

# %%
# LC25000 Dataset
with open(os.path.abspath(Source_dir_train1), "rb") as f:
    LC25000_train1 = pickle.load(f)
with open(os.path.abspath(Source_dir_train2), "rb") as f:
    LC25000_train2 = pickle.load(f)
with open(os.path.abspath(Source_dir_train3), "rb") as f:
    LC25000_train3 = pickle.load(f)
with open(os.path.abspath(Source_dir_train4), "rb") as f:
    LC25000_train4 = pickle.load(f)
with open(os.path.abspath(Source_dir_train5), "rb") as f:
    LC25000_train5 = pickle.load(f)
with open(os.path.abspath(Source_dir_test1), "rb") as f:
    LC25000_test1 = pickle.load(f)
with open(os.path.abspath(Source_dir_test2), "rb") as f:
    LC25000_test2 = pickle.load(f)

# %%
LC25000_train_data = LC25000_train1['train'] + LC25000_train2['train'] + LC25000_train3['train'] + LC25000_train4['train'] + LC25000_train5['train']
LC25000_train_labels = np.concatenate((LC25000_train1['train_label'],LC25000_train2['train_label'],LC25000_train3['train_label'],LC25000_train4['train_label'],LC25000_train5['train_label']))
LC25000_test_data = LC25000_test1['test'] + LC25000_test2['test']
LC25000_test_labels = np.concatenate((LC25000_test1['test_label'],LC25000_test2['test_label']))

# %%
LC25000_train_lab = tf.one_hot(LC25000_train_labels, depth=3)
LC25000_test_lab = tf.one_hot(LC25000_test_labels, depth=3)

# %%
LC25000_train_data = np.array(LC25000_train_data, dtype=np.float32)
LC25000_test_data = np.array(LC25000_test_data, dtype=np.float32)

# %%
print("The shape of LC25000_train_data: ", LC25000_train_data.shape)
print("The shape of LC25000_train_labels: ", LC25000_train_labels.shape)
print("The shape of LC25000_test_data: ", LC25000_test_data.shape)
print("The shape of LC25000_test_labels: " ,LC25000_test_labels.shape)
# Out:
# The shape of LC25000_train_data:  (6400, 128, 128, 3)
# The shape of LC25000_train_labels:  (6400,)
# The shape of LC25000_test_data:  (1600, 128, 128, 3)
# The shape of LC25000_test_labels:  (1600,)

# %% [markdown]
# ## TCGA Cyclegan Dataset

# %%
# TCGA Dataset
with open(os.path.abspath(Target_cyclegan_dir_train), "rb") as f:
    TCGA_cyclegan_train = pickle.load(f)
with open(os.path.abspath(Target_cyclegan_dir_test), "rb") as f:
    TCGA_cyclegan_test = pickle.load(f)

# %%
TCGA_cyclegan_train_data = TCGA_cyclegan_train['train']
TCGA_cyclegan_train_labels = TCGA_cyclegan_train['train_label']
TCGA_cyclegan_test_data = TCGA_cyclegan_test['test']
TCGA_cyclegan_test_labels = TCGA_cyclegan_test['test_label']

# %%
TCGA_cyclegan_train_lab = tf.one_hot(TCGA_cyclegan_train_labels, depth=3)
TCGA_cyclegan_test_lab = tf.one_hot(TCGA_cyclegan_test_labels, depth=3)

# %%
TCGA_cyclegan_train_data = np.array(TCGA_cyclegan_train_data, dtype=np.float32)
TCGA_cyclegan_test_data = np.array(TCGA_cyclegan_test_data, dtype=np.float32)

# %%
print("The shape of TCGA_cyclegan_train_data: ", TCGA_cyclegan_train_data.shape)
print("The shape of TCGA_cyclegan_train_labels: ", TCGA_cyclegan_train_labels.shape)
print("The shape of TCGA_cyclegan_test_data: ", TCGA_cyclegan_test_data.shape)
print("The shape of TCGA_cyclegan_test_labels: " , TCGA_cyclegan_test_labels.shape)
# Out:
# The shape of TCGA_cyclegan_train_data:  (6400, 128, 128, 3)
# The shape of TCGA_cyclegan_train_labels:  (6400,)
# The shape of TCGA_cyclegan_test_data:  (6400, 128, 128, 3)
# The shape of TCGA_cyclegan_test_labels:  (6400,)

# %% [markdown]
# ## Datasets Visualization

# %%
# random show images
plt.subplots(1,2,figsize=(8,8))
ax1=plt.subplot(1,2,1)
sample1 = random.choice(LC25000_train_data)
img1 = array_to_img(sample1)
plt.title("LC25000_train_data")
plt.imshow(img1)
ax1=plt.subplot(1,2,2)
sample2 = random.choice(LC25000_test_data)
img2 = array_to_img(sample2)
plt.title("LC25000_test_data")
plt.imshow(img2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# random show images
plt.subplots(1,2,figsize=(10,10))
ax1=plt.subplot(1,2,1)
sample1 = random.choice(TCGA_cyclegan_train_data)
img1 = array_to_img(sample1)
plt.title("TCGA_cyclegan_train_data")
plt.imshow(img1)
ax1=plt.subplot(1,2,2)
sample2 = random.choice(TCGA_cyclegan_test_data)
img2 = array_to_img(sample2)
plt.title("TCGA_cyclegan_test_data")
plt.imshow(img2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # Domain Adaptation

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Feature Extractor - ResNet50V2

# %%
resnet50 = ResNet50(include_top=False, input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, CHANNELS), pooling="avg")

first_layer = resnet50.get_layer('conv5_block2_out')
inputs = Input(first_layer.output_shape[1:])

for layer in resnet50.layers[resnet50.layers.index(first_layer)+1:]:
    if layer.name == "conv5_block3_1_conv":
        x = layer(inputs)
    elif layer.name == "conv5_block3_add":  # change name
        x = layer([inputs, x])
    else:
        if layer.name == "conv5_block3_preact_bn":
            pass
        else:
            x = layer(x)

first_blocks = Model(resnet50.input, first_layer.output)
last_block = Model(inputs, x)

# %%
def load_resnet50(path="./Model/DANN_Model/resnet50_last_block.hdf5"):
    model = load_model(path)
    for i in range(len(model.layers)):
        if model.layers[i].__class__.__name__ == "BatchNormalization":
            model.layers[i].trainable = False
    return model

last_block.summary()
last_block.save("./Model/DANN_Model/resnet50_last_block.hdf5")
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 4, 4, 2048)  0           []
#                                 ]
#
#  conv5_block3_1_conv (Conv2D)   (None, 4, 4, 512)    1049088     ['input_4[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_1_conv[1][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_1_bn[1][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block3_1_relu[1][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_2_conv[1][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_2_bn[1][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block3_2_relu[1][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block3_3_conv[1][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 4, 4, 2048)   0           ['input_4[0][0]',
#                                                                   'conv5_block3_3_bn[1][0]']
#
#  conv5_block3_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block3_add[1][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[1][0]']
#  2D)
#
# ==================================================================================================
# Total params: 4,471,808
# Trainable params: 4,465,664
# Non-trainable params: 6,144
# __________________________________________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ### Extract the features

# %%
LC25000_train_data_ex = first_blocks.predict(preprocess_input(np.stack(LC25000_train_data)))
TCGA_cyclegan_train_data_ex = first_blocks.predict(preprocess_input(np.stack(TCGA_cyclegan_train_data)))
TCGA_cyclegan_test_data_ex = first_blocks.predict(preprocess_input(np.stack(TCGA_cyclegan_test_data)))


print("LC25000_train_data (source) shape: %s"%str(LC25000_train_data.shape))
print("TCGA_cyclegan_train_data (target) shape: %s"%str(TCGA_cyclegan_train_data.shape))
# Out:
# LC25000_train_data (source) shape: (6400, 128, 128, 3)
# TCGA_cyclegan_train_data (target) shape: (6400, 128, 128, 3)

# %% [markdown]
# ### Prepare Datasets

# %%
source_dataset = tf.data.Dataset.from_tensor_slices((LC25000_train_data_ex, LC25000_train_lab)).shuffle(1000).batch(BATCH_SIZE*2)
da_dataset = tf.data.Dataset.from_tensor_slices((LC25000_train_data_ex, LC25000_train_lab, TCGA_cyclegan_train_data_ex, TCGA_cyclegan_train_lab)).shuffle(1000).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((TCGA_cyclegan_test_data_ex, TCGA_cyclegan_test_lab)).shuffle(1000).batch(BATCH_SIZE*2) #Test Dataset over Target Domain
test_dataset2 = tf.data.Dataset.from_tensor_slices((TCGA_cyclegan_train_data_ex, TCGA_cyclegan_train_lab)).shuffle(1000).batch(BATCH_SIZE*2) #Test Dataset over Target (used for training)

# %% [markdown]
# ### ResNet50V2 Model

# %%
feature_extractor_resnet = load_resnet50()

class DANN_resnet(Model):
    def __init__(self):
        super().__init__()
        
        #Feature Extractor
        self.ResNet_load = feature_extractor_resnet
        
        #Label Predictor
        self.max_norm = 0.5
        self.dropout= 0.5
        self.label_predictor_layer0 = Dense(1024, activation="relu",
                                            kernel_constraint=MaxNorm(self.max_norm),
                                            bias_constraint=MaxNorm(self.max_norm))
        self.label_predictor_layer1 = Dropout(self.dropout)
        self.label_predictor_layer2 = Dense(1024, activation="relu",
                                            kernel_constraint=MaxNorm(self.max_norm),
                                            bias_constraint=MaxNorm(self.max_norm))
        self.label_predictor_layer3 = Dropout(self.dropout)
        self.label_predictor_layer4 = Dense(3, activation=None)
        
        #Domain Predictor
        self.domain_predictor_layer0 = GradientReversalLayer()
        self.domain_predictor_layer1 = Dense(100, activation='relu')
        self.domain_predictor_layer2 = Dense(2, activation=None)
        
    def call(self, x, train=False, source_train=True, lamda=1.0):
        #Feature Extractor
        x = self.ResNet_load(x)
        #print("x:", x)
     

        feature = tf.reshape(x, [-1, 32 * 32 * 2])
        #print("feature: ", feature)
        
        #Label Predictor
        if source_train is True:
            feature_slice = feature
            #print("feature_slice: ",feature_slice)
        else:
            feature_slice = tf.slice(feature, [0, 0], [feature.shape[0] // 2, -1])
            #print("feature_slice: ",feature_slice)
        
        lp_x = self.label_predictor_layer0(feature_slice)
        lp_x = self.label_predictor_layer1(lp_x)
        lp_x = self.label_predictor_layer2(lp_x)
        lp_x = self.label_predictor_layer3(lp_x)
        l_logits = self.label_predictor_layer4(lp_x)
        
        #Domain Predictor
        if source_train is True:
            #print("l_logits: " ,l_logits)
            return l_logits
        else:
            dp_x = self.domain_predictor_layer0(feature, lamda)    #GradientReversalLayer
            dp_x = self.domain_predictor_layer1(dp_x)
            d_logits = self.domain_predictor_layer2(dp_x)
            #print("l_logits-1: " ,l_logits)
            #print("d_logits-1", d_logits)
            return l_logits, d_logits


#model = DANN_resnet()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ## Gradient Reversal Layer

# %%
@tf.custom_gradient
def gradient_reverse(x, lamda=1.0):
    y = tf.identity(x)
    
    def grad(dy):
        return lamda * -dy, None
    
    return y, grad


class GradientReversalLayer(tf.keras.layers.Layer):
    def __init__(self):
        super().__init__()
    
    def call(self, x, lamda=1.0):
        return gradient_reverse(x, lamda)

# %% [markdown]
# ## Define Loss and Optimizer

# %%
def loss_func(input_logits, target_labels):
    return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=input_logits, labels=target_labels))


def get_loss(l_logits, labels, d_logits=None, domain=None):
    if d_logits is None:
        #print("l_logits",l_logits)
        #print("labels",labels)
        return loss_func(l_logits, labels)
    else:
        #print("l_logits-2",l_logits)
        #print("labels-2",labels)
        #print("d_logits-2",d_logits)
        #print("domain-2",domain.shape)        
        return loss_func(l_logits, labels) + loss_func(d_logits, domain)

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate= learning_rate,
    decay_steps=10000,
    decay_rate=0.9)

model_optimizer = tf.optimizers.Adam(learning_rate=lr_schedule)
#model_optimizer = tf.optimizers.SGD(learning_rate=lr_schedule)


#model_optimizer = tf.optimizers.Adam(learning_rate=1e-4)
# model_optimizer = tf.optimizers.SGD(learning_rate=1e-4)

# %% [markdown]
# ## Configuration of Training

# %%
domain_labels = np.vstack([np.tile([1., 0.], [BATCH_SIZE, 1]),
                           np.tile([0., 1.], [BATCH_SIZE, 1])])
domain_labels = domain_labels.astype('float32')

epoch_accuracy = tf.keras.metrics.CategoricalAccuracy()

source_acc = []  # Source Domain Accuracy while Source-only Training
da_acc = []      # Source Domain Accuracy while DA-training
test_acc = []    # Testing Dataset (Target Domain) Accuracy 
test2_acc = []   # Target Domain (used for Training) Accuracy

def reset_list():
    source_acc.clear() 
    da_acc.clear()
    test_acc.clear()
    test2_acc.clear()

# %%
@tf.function
def train_step_source(s_images, s_labels, lamda=1.0):
    images = s_images
    labels = s_labels
    
    with tf.GradientTape() as tape:
        output = model(images, train=True, source_train=True, lamda=lamda)
        
        model_loss = get_loss(output, labels)
        epoch_accuracy(output, labels)
        
    gradients_mdan = tape.gradient(model_loss, model.trainable_variables)
    model_optimizer.apply_gradients(zip(gradients_mdan, model.trainable_variables))


@tf.function
def train_step_da(s_images, s_labels, t_images=None, t_labels=None, lamda=1.0):
    images = tf.concat([s_images, t_images], 0)
    labels = s_labels
    
    with tf.GradientTape() as tape:
        output = model(images, train=True, source_train=False, lamda=lamda)
        
        model_loss = get_loss(output[0], labels, output[1], domain_labels)
        epoch_accuracy(output[0], labels)
        
    gradients_mdan = tape.gradient(model_loss, model.trainable_variables)
    model_optimizer.apply_gradients(zip(gradients_mdan, model.trainable_variables))


@tf.function
def test_step(t_images, t_labels):
    images = t_images
    labels = t_labels
    
    output = model(images, train=False, source_train=True)
    epoch_accuracy(output, labels)



def train(train_mode, epochs):
    
    if train_mode == 'source':
        dataset = source_dataset
        train_func = train_step_source
        acc_list = source_acc
    elif train_mode == 'domain-adaptation':
        dataset = da_dataset
        train_func = train_step_da
        acc_list = da_acc
    else:
        raise ValueError("Unknown training Mode")
    

    for epoch in range(epochs):
        p = float(epoch) / epochs
        lamda = 2 / (1 + np.exp(-gamma * p, dtype=np.float32)) - 1
        lamda = lamda.astype('float32')

        
        for batch in dataset:
            train_func(*batch, lamda=lamda)
        
        print("Training: Epoch {} :\t Source Accuracy : {:.3%}".format(epoch, epoch_accuracy.result()), end='  |  ')
        acc_list.append(epoch_accuracy.result())
        test()
        epoch_accuracy.reset_states()


def test():
    epoch_accuracy.reset_states()
    
    #Testing Dataset (Target Domain)

    for batch in test_dataset:
        test_step(*batch)
        
    print("Testing Accuracy : {:.3%}".format(epoch_accuracy.result()), end='  |  ')
    test_acc.append(epoch_accuracy.result())
    epoch_accuracy.reset_states()
    
    #Target Domain (used for Training)
    for batch in test_dataset2:
        test_step(*batch)
    
    print("Target Domain Accuracy : {:.3%}".format(epoch_accuracy.result()))
    test2_acc.append(epoch_accuracy.result())
    epoch_accuracy.reset_states()

# %% [markdown]
# # Training

# %% [markdown]
# ### domain-adaptation train : SGD=1e-6, gamma = 10

# %%
reset_list()

EPOCH= 60
model = DANN_resnet()
gamma = 10
learning_rate = 1e-6
model_optimizer = tf.optimizers.SGD(learning_rate=lr_schedule)
# model_optimizer = tf.optimizers.RMSprop(learning_rate=1e-5)
train('domain-adaptation', EPOCH)

#Plot Results
x_axis = [i for i in range(0, EPOCH)]

plt.title("Accuracy of DANN Model - Domain-adaptation Training")
plt.plot(x_axis, da_acc, label="source accuracy")
plt.plot(x_axis, test_acc, label="testing accuracy")
plt.plot(x_axis, test2_acc, label="target accuracy")
plt.legend()
# Out:
# Training: Epoch 0 :	 Source Accuracy : 57.187%  |  Testing Accuracy : 9.969%  |  Target Domain Accuracy : 9.672%
# Training: Epoch 1 :	 Source Accuracy : 77.609%  |  Testing Accuracy : 29.750%  |  Target Domain Accuracy : 28.547%
# Training: Epoch 2 :	 Source Accuracy : 83.172%  |  Testing Accuracy : 36.297%  |  Target Domain Accuracy : 35.484%
# Training: Epoch 3 :	 Source Accuracy : 86.203%  |  Testing Accuracy : 39.062%  |  Target Domain Accuracy : 38.781%
# Training: Epoch 4 :	 Source Accuracy : 88.281%  |  Testing Accuracy : 40.375%  |  Target Domain Accuracy : 39.969%
# Training: Epoch 5 :	 Source Accuracy : 89.234%  |  Testing Accuracy : 41.172%  |  Target Domain Accuracy : 40.797%
# Training: Epoch 6 :	 Source Accuracy : 90.141%  |  Testing Accuracy : 41.672%  |  Target Domain Accuracy : 41.219%
# Training: Epoch 7 :	 Source Accuracy : 90.797%  |  Testing Accuracy : 41.984%  |  Target Domain Accuracy : 41.641%
# Training: Epoch 8 :	 Source Accuracy : 90.891%  |  Testing Accuracy : 42.141%  |  Target Domain Accuracy : 41.984%
# Training: Epoch 9 :	 Source Accuracy : 91.297%  |  Testing Accuracy : 42.437%  |  Target Domain Accuracy : 42.250%
# Training: Epoch 10 :	 Source Accuracy : 91.703%  |  Testing Accuracy : 42.687%  |  Target Domain Accuracy : 42.609%
# Training: Epoch 11 :	 Source Accuracy : 91.781%  |  Testing Accuracy : 42.672%  |  Target Domain Accuracy : 42.922%
# Training: Epoch 12 :	 Source Accuracy : 92.250%  |  Testing Accuracy : 42.922%  |  Target Domain Accuracy : 42.891%
# Training: Epoch 13 :	 Source Accuracy : 92.531%  |  Testing Accuracy : 43.125%  |  Target Domain Accuracy : 43.500%
# Training: Epoch 14 :	 Source Accuracy : 93.125%  |  Testing Accuracy : 45.047%  |  Target Domain Accuracy : 44.531%
# Training: Epoch 15 :	 Source Accuracy : 85.656%  |  Testing Accuracy : 48.625%  |  Target Domain Accuracy : 48.859%
# Training: Epoch 16 :	 Source Accuracy : 82.766%  |  Testing Accuracy : 50.000%  |  Target Domain Accuracy : 50.000%
# Training: Epoch 17 :	 Source Accuracy : 85.297%  |  Testing Accuracy : 45.594%  |  Target Domain Accuracy : 45.312%
# Training: Epoch 18 :	 Source Accuracy : 84.484%  |  Testing Accuracy : 45.891%  |  Target Domain Accuracy : 45.609%
# Training: Epoch 19 :	 Source Accuracy : 88.313%  |  Testing Accuracy : 44.828%  |  Target Domain Accuracy : 44.797%
# Training: Epoch 20 :	 Source Accuracy : 88.172%  |  Testing Accuracy : 48.203%  |  Target Domain Accuracy : 48.891%
# Training: Epoch 21 :	 Source Accuracy : 89.281%  |  Testing Accuracy : 47.031%  |  Target Domain Accuracy : 46.719%
# Training: Epoch 22 :	 Source Accuracy : 89.625%  |  Testing Accuracy : 46.781%  |  Target Domain Accuracy : 46.781%
# Training: Epoch 23 :	 Source Accuracy : 90.172%  |  Testing Accuracy : 45.266%  |  Target Domain Accuracy : 45.359%
# Training: Epoch 24 :	 Source Accuracy : 91.250%  |  Testing Accuracy : 44.484%  |  Target Domain Accuracy : 44.641%
# Training: Epoch 25 :	 Source Accuracy : 91.859%  |  Testing Accuracy : 46.156%  |  Target Domain Accuracy : 45.672%
# Training: Epoch 26 :	 Source Accuracy : 93.063%  |  Testing Accuracy : 45.281%  |  Target Domain Accuracy : 45.219%
# Training: Epoch 27 :	 Source Accuracy : 92.563%  |  Testing Accuracy : 46.422%  |  Target Domain Accuracy : 45.953%
# Training: Epoch 28 :	 Source Accuracy : 94.766%  |  Testing Accuracy : 46.781%  |  Target Domain Accuracy : 46.578%
# Training: Epoch 29 :	 Source Accuracy : 95.031%  |  Testing Accuracy : 45.281%  |  Target Domain Accuracy : 44.859%
# Training: Epoch 30 :	 Source Accuracy : 94.437%  |  Testing Accuracy : 46.922%  |  Target Domain Accuracy : 46.797%
# Training: Epoch 31 :	 Source Accuracy : 95.844%  |  Testing Accuracy : 46.875%  |  Target Domain Accuracy : 46.703%
# Training: Epoch 32 :	 Source Accuracy : 95.781%  |  Testing Accuracy : 45.891%  |  Target Domain Accuracy : 45.578%
# Training: Epoch 33 :	 Source Accuracy : 95.000%  |  Testing Accuracy : 46.500%  |  Target Domain Accuracy : 45.812%
# Training: Epoch 34 :	 Source Accuracy : 95.187%  |  Testing Accuracy : 45.781%  |  Target Domain Accuracy : 45.469%
# Training: Epoch 35 :	 Source Accuracy : 94.500%  |  Testing Accuracy : 45.859%  |  Target Domain Accuracy : 45.547%
# Training: Epoch 36 :	 Source Accuracy : 95.609%  |  Testing Accuracy : 44.641%  |  Target Domain Accuracy : 44.453%
# Training: Epoch 37 :	 Source Accuracy : 94.687%  |  Testing Accuracy : 46.187%  |  Target Domain Accuracy : 45.672%
# Training: Epoch 38 :	 Source Accuracy : 95.484%  |  Testing Accuracy : 46.172%  |  Target Domain Accuracy : 45.719%
# Training: Epoch 39 :	 Source Accuracy : 95.906%  |  Testing Accuracy : 45.625%  |  Target Domain Accuracy : 45.281%
# Training: Epoch 40 :	 Source Accuracy : 96.016%  |  Testing Accuracy : 45.859%  |  Target Domain Accuracy : 45.391%
# Training: Epoch 41 :	 Source Accuracy : 96.094%  |  Testing Accuracy : 45.531%  |  Target Domain Accuracy : 45.141%
# Training: Epoch 42 :	 Source Accuracy : 96.109%  |  Testing Accuracy : 45.547%  |  Target Domain Accuracy : 45.109%
# Training: Epoch 43 :	 Source Accuracy : 96.391%  |  Testing Accuracy : 45.406%  |  Target Domain Accuracy : 45.000%
# Training: Epoch 44 :	 Source Accuracy : 96.656%  |  Testing Accuracy : 45.328%  |  Target Domain Accuracy : 45.156%
# Training: Epoch 45 :	 Source Accuracy : 95.859%  |  Testing Accuracy : 45.516%  |  Target Domain Accuracy : 45.188%
# Training: Epoch 46 :	 Source Accuracy : 96.656%  |  Testing Accuracy : 45.391%  |  Target Domain Accuracy : 45.078%
# Training: Epoch 47 :	 Source Accuracy : 96.625%  |  Testing Accuracy : 44.922%  |  Target Domain Accuracy : 44.547%
# Training: Epoch 48 :	 Source Accuracy : 96.641%  |  Testing Accuracy : 45.297%  |  Target Domain Accuracy : 44.938%
# Training: Epoch 49 :	 Source Accuracy : 96.547%  |  Testing Accuracy : 44.781%  |  Target Domain Accuracy : 44.781%
# Training: Epoch 50 :	 Source Accuracy : 96.812%  |  Testing Accuracy : 45.578%  |  Target Domain Accuracy : 45.203%
# Training: Epoch 51 :	 Source Accuracy : 96.938%  |  Testing Accuracy : 45.188%  |  Target Domain Accuracy : 45.063%
# Training: Epoch 52 :	 Source Accuracy : 96.688%  |  Testing Accuracy : 45.937%  |  Target Domain Accuracy : 45.594%
# Training: Epoch 53 :	 Source Accuracy : 97.078%  |  Testing Accuracy : 44.000%  |  Target Domain Accuracy : 44.109%
# Training: Epoch 54 :	 Source Accuracy : 96.156%  |  Testing Accuracy : 44.734%  |  Target Domain Accuracy : 44.516%
# Training: Epoch 55 :	 Source Accuracy : 96.844%  |  Testing Accuracy : 44.484%  |  Target Domain Accuracy : 44.344%
# Training: Epoch 56 :	 Source Accuracy : 96.750%  |  Testing Accuracy : 45.281%  |  Target Domain Accuracy : 45.016%
# Training: Epoch 57 :	 Source Accuracy : 97.219%  |  Testing Accuracy : 44.844%  |  Target Domain Accuracy : 44.703%
# Training: Epoch 58 :	 Source Accuracy : 96.750%  |  Testing Accuracy : 44.547%  |  Target Domain Accuracy : 44.578%
# Training: Epoch 59 :	 Source Accuracy : 96.750%  |  Testing Accuracy : 44.922%  |  Target Domain Accuracy : 44.797%

# %%
import pandas as pd

train_data = pd.DataFrame(
    {"source accuracy": da_acc,
     "testing accuracy": test_acc,
     "target accuracy": test2_acc
    })
train_data.to_csv("./Model/DANN_Model/DANN/DANN_Resnet_SGD_1e-6_g10_cyclegan.csv")

# %% [markdown]
# ### source train : SGD=1e-6, gamma = 10

# %%
reset_list()

EPOCH=60
model = DANN_resnet()
gamma = 10
learning_rate = 1e-6
model_optimizer = tf.optimizers.SGD(learning_rate=lr_schedule)
# model_optimizer = tf.optimizers.RMSprop(learning_rate=1e-5)
train('source', EPOCH)

#Plot Results
x_axis = [i for i in range(0, EPOCH)]

plt.title("Accuracy of DANN Model - Domain-adaptation Training")
plt.plot(x_axis, source_acc, label="source accuracy")
plt.plot(x_axis, test_acc, label="testing accuracy")
plt.plot(x_axis, test2_acc, label="target accuracy")
plt.legend()
# Out:
# Training: Epoch 0 :	 Source Accuracy : 79.531%  |  Testing Accuracy : 43.922%  |  Target Domain Accuracy : 44.000%
# Training: Epoch 1 :	 Source Accuracy : 86.953%  |  Testing Accuracy : 43.938%  |  Target Domain Accuracy : 43.938%
# Training: Epoch 2 :	 Source Accuracy : 91.672%  |  Testing Accuracy : 43.781%  |  Target Domain Accuracy : 43.828%
# Training: Epoch 3 :	 Source Accuracy : 92.453%  |  Testing Accuracy : 43.859%  |  Target Domain Accuracy : 43.875%
# Training: Epoch 4 :	 Source Accuracy : 92.953%  |  Testing Accuracy : 43.828%  |  Target Domain Accuracy : 43.875%
# Training: Epoch 5 :	 Source Accuracy : 93.875%  |  Testing Accuracy : 43.797%  |  Target Domain Accuracy : 43.875%
# Training: Epoch 6 :	 Source Accuracy : 94.250%  |  Testing Accuracy : 43.797%  |  Target Domain Accuracy : 43.859%
# Training: Epoch 7 :	 Source Accuracy : 93.672%  |  Testing Accuracy : 43.781%  |  Target Domain Accuracy : 43.828%
# Training: Epoch 8 :	 Source Accuracy : 95.266%  |  Testing Accuracy : 43.781%  |  Target Domain Accuracy : 43.859%
# Training: Epoch 9 :	 Source Accuracy : 94.734%  |  Testing Accuracy : 43.859%  |  Target Domain Accuracy : 43.781%
# Training: Epoch 10 :	 Source Accuracy : 93.703%  |  Testing Accuracy : 43.859%  |  Target Domain Accuracy : 43.859%
# Training: Epoch 11 :	 Source Accuracy : 95.609%  |  Testing Accuracy : 43.828%  |  Target Domain Accuracy : 43.797%
# Training: Epoch 12 :	 Source Accuracy : 95.203%  |  Testing Accuracy : 43.844%  |  Target Domain Accuracy : 43.766%
# Training: Epoch 13 :	 Source Accuracy : 95.391%  |  Testing Accuracy : 43.906%  |  Target Domain Accuracy : 43.734%
# Training: Epoch 14 :	 Source Accuracy : 94.406%  |  Testing Accuracy : 43.844%  |  Target Domain Accuracy : 43.672%
# Training: Epoch 15 :	 Source Accuracy : 95.469%  |  Testing Accuracy : 43.859%  |  Target Domain Accuracy : 43.797%
# Training: Epoch 16 :	 Source Accuracy : 95.547%  |  Testing Accuracy : 43.844%  |  Target Domain Accuracy : 43.703%
# Training: Epoch 17 :	 Source Accuracy : 95.187%  |  Testing Accuracy : 43.813%  |  Target Domain Accuracy : 43.641%
# Training: Epoch 18 :	 Source Accuracy : 94.953%  |  Testing Accuracy : 43.828%  |  Target Domain Accuracy : 43.656%
# Training: Epoch 19 :	 Source Accuracy : 95.844%  |  Testing Accuracy : 43.813%  |  Target Domain Accuracy : 43.609%
# Training: Epoch 20 :	 Source Accuracy : 94.375%  |  Testing Accuracy : 43.813%  |  Target Domain Accuracy : 43.578%
# Training: Epoch 21 :	 Source Accuracy : 95.156%  |  Testing Accuracy : 43.703%  |  Target Domain Accuracy : 43.609%
# Training: Epoch 22 :	 Source Accuracy : 95.125%  |  Testing Accuracy : 43.719%  |  Target Domain Accuracy : 43.609%
# Training: Epoch 23 :	 Source Accuracy : 95.578%  |  Testing Accuracy : 43.734%  |  Target Domain Accuracy : 43.625%
# Training: Epoch 24 :	 Source Accuracy : 95.656%  |  Testing Accuracy : 43.719%  |  Target Domain Accuracy : 43.625%
# Training: Epoch 25 :	 Source Accuracy : 95.859%  |  Testing Accuracy : 43.625%  |  Target Domain Accuracy : 43.656%
# Training: Epoch 26 :	 Source Accuracy : 95.703%  |  Testing Accuracy : 43.656%  |  Target Domain Accuracy : 43.625%
# Training: Epoch 27 :	 Source Accuracy : 96.234%  |  Testing Accuracy : 43.562%  |  Target Domain Accuracy : 43.641%
# Training: Epoch 28 :	 Source Accuracy : 96.375%  |  Testing Accuracy : 43.578%  |  Target Domain Accuracy : 43.641%
# Training: Epoch 29 :	 Source Accuracy : 96.156%  |  Testing Accuracy : 43.625%  |  Target Domain Accuracy : 43.531%
# Training: Epoch 30 :	 Source Accuracy : 95.781%  |  Testing Accuracy : 43.594%  |  Target Domain Accuracy : 43.531%
# Training: Epoch 31 :	 Source Accuracy : 96.281%  |  Testing Accuracy : 43.641%  |  Target Domain Accuracy : 43.531%
# Training: Epoch 32 :	 Source Accuracy : 95.891%  |  Testing Accuracy : 43.594%  |  Target Domain Accuracy : 43.578%
# Training: Epoch 33 :	 Source Accuracy : 95.875%  |  Testing Accuracy : 43.594%  |  Target Domain Accuracy : 43.578%
# Training: Epoch 34 :	 Source Accuracy : 95.953%  |  Testing Accuracy : 43.594%  |  Target Domain Accuracy : 43.594%
# Training: Epoch 35 :	 Source Accuracy : 95.984%  |  Testing Accuracy : 43.531%  |  Target Domain Accuracy : 43.578%
# Training: Epoch 36 :	 Source Accuracy : 96.484%  |  Testing Accuracy : 43.562%  |  Target Domain Accuracy : 43.562%
# Training: Epoch 37 :	 Source Accuracy : 95.984%  |  Testing Accuracy : 43.516%  |  Target Domain Accuracy : 43.547%
# Training: Epoch 38 :	 Source Accuracy : 96.141%  |  Testing Accuracy : 43.531%  |  Target Domain Accuracy : 43.547%
# Training: Epoch 39 :	 Source Accuracy : 95.609%  |  Testing Accuracy : 43.500%  |  Target Domain Accuracy : 43.484%
# Training: Epoch 40 :	 Source Accuracy : 96.344%  |  Testing Accuracy : 43.328%  |  Target Domain Accuracy : 43.344%
# Training: Epoch 41 :	 Source Accuracy : 95.969%  |  Testing Accuracy : 43.375%  |  Target Domain Accuracy : 43.375%
# Training: Epoch 42 :	 Source Accuracy : 96.375%  |  Testing Accuracy : 43.344%  |  Target Domain Accuracy : 43.344%
# Training: Epoch 43 :	 Source Accuracy : 96.375%  |  Testing Accuracy : 43.422%  |  Target Domain Accuracy : 43.422%
# Training: Epoch 44 :	 Source Accuracy : 96.609%  |  Testing Accuracy : 43.266%  |  Target Domain Accuracy : 43.328%
# Training: Epoch 45 :	 Source Accuracy : 96.047%  |  Testing Accuracy : 43.250%  |  Target Domain Accuracy : 43.297%
# Training: Epoch 46 :	 Source Accuracy : 96.469%  |  Testing Accuracy : 43.281%  |  Target Domain Accuracy : 43.406%
# Training: Epoch 47 :	 Source Accuracy : 96.500%  |  Testing Accuracy : 43.187%  |  Target Domain Accuracy : 43.297%
# Training: Epoch 48 :	 Source Accuracy : 96.000%  |  Testing Accuracy : 43.172%  |  Target Domain Accuracy : 43.281%
# Training: Epoch 49 :	 Source Accuracy : 96.500%  |  Testing Accuracy : 43.187%  |  Target Domain Accuracy : 43.281%
# Training: Epoch 50 :	 Source Accuracy : 96.266%  |  Testing Accuracy : 43.156%  |  Target Domain Accuracy : 43.312%
# Training: Epoch 51 :	 Source Accuracy : 96.516%  |  Testing Accuracy : 43.203%  |  Target Domain Accuracy : 43.312%
# Training: Epoch 52 :	 Source Accuracy : 96.359%  |  Testing Accuracy : 43.187%  |  Target Domain Accuracy : 43.328%
# Training: Epoch 53 :	 Source Accuracy : 96.234%  |  Testing Accuracy : 43.125%  |  Target Domain Accuracy : 43.250%
# Training: Epoch 54 :	 Source Accuracy : 96.312%  |  Testing Accuracy : 43.172%  |  Target Domain Accuracy : 43.234%
# Training: Epoch 55 :	 Source Accuracy : 96.500%  |  Testing Accuracy : 43.016%  |  Target Domain Accuracy : 43.234%
# Training: Epoch 56 :	 Source Accuracy : 96.078%  |  Testing Accuracy : 42.969%  |  Target Domain Accuracy : 43.172%
# Training: Epoch 57 :	 Source Accuracy : 96.266%  |  Testing Accuracy : 43.031%  |  Target Domain Accuracy : 43.203%
# Training: Epoch 58 :	 Source Accuracy : 96.641%  |  Testing Accuracy : 43.031%  |  Target Domain Accuracy : 43.172%
# Training: Epoch 59 :	 Source Accuracy : 96.375%  |  Testing Accuracy : 43.109%  |  Target Domain Accuracy : 43.297%

# %%
import pandas as pd

train_data = pd.DataFrame(
    {"source accuracy": source_acc,
     "testing accuracy": test_acc,
     "target accuracy": test2_acc
    })
train_data.to_csv("./Model/DANN_Model/DANN_source_Resnet_SGD_1e-6_g10_cyclegan.csv")
